# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

import xgboost as xgb
from xgboost import XGBClassifier
from xgboost.core import XGBoostError
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


import csv

import cupy as cp

import gc

# %%
df = pd.read_csv("../../story_dataset.csv")
df
# Out:
#       prompt_id                                 prompt  \
# 0             1    Once upon a time there was a dragon
# 1             1    Once upon a time there was a dragon
# 2             1    Once upon a time there was a dragon
# 3             1    Once upon a time there was a dragon
# 4             1    Once upon a time there was a dragon
# ...         ...                                    ...
# 9995         10  Once upon a time there was a poor boy
# 9996         10  Once upon a time there was a poor boy
# 9997         10  Once upon a time there was a poor boy
# 9998         10  Once upon a time there was a poor boy
# 9999         10  Once upon a time there was a poor boy
#
#                                                   story  \
# 0     Once upon a time there was a dragon. It was bi...
# 1     Once upon a time there was a dragon. He loved ...
# 2     Once upon a time there was a dragon named Sam....
# 3     Once upon a time there was a dragon. He was a ...
# 4     Once upon a time there was a dragon. The drago...
# ...                                                 ...
# 9995  Once upon a time there was a poor boy named Ti...
# 9996  Once upon a time there was a poor boy named Ti...
# 9997  Once upon a time there was a poor boy named Ti...
# 9998  Once upon a time there was a poor boy named Ti...
# 9999  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story
# 0      ./hidden_states/prompt_1.npz                  273
# 1      ./hidden_states/prompt_1.npz                  246
# 2      ./hidden_states/prompt_1.npz                  397
# 3      ./hidden_states/prompt_1.npz                  294
# 4      ./hidden_states/prompt_1.npz                  296
# ...                             ...                  ...
# 9995  ./hidden_states/prompt_10.npz                  315
# 9996  ./hidden_states/prompt_10.npz                  270
# 9997  ./hidden_states/prompt_10.npz                  206
# 9998  ./hidden_states/prompt_10.npz                  375
# 9999  ./hidden_states/prompt_10.npz                  341
#
# [10000 rows x 5 columns]

# %%
hidden_states_by_cl = {}
curr_labels = {}
NUM_PROMPTS = 10
layers = [i for i in range(3, 9)]

# %%
max_story_len = max(df[:NUM_PROMPTS*1000]["len_generated_story"])
max_story_len
# Out:
# 522

# %%
df[df["len_generated_story"] >= max_story_len]
# Out:
#       prompt_id                                 prompt  \
# 9851         10  Once upon a time there was a poor boy
#
#                                                   story  \
# 9851  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story
# 9851  ./hidden_states/prompt_10.npz                  522

# %%
min_story_len = min(df["len_generated_story"])
min_story_len
# Out:
# 37

# %%
context_levels = [0] #get hs used to generate second token
context_levels.extend([i for i in range(23, max_story_len, 25)]) #actual context level is context_level + 2 (gather hs to generate the context_level + 2 token)

# %%
def safe_split(total, train_ratio=0.8):
    train = int(train_ratio * total)   # floor
    test  = total - train              # leftover
    return train, test

def build_dataset(curr_context_level_hs, curr_labels, train_ratio=0.8):
    """
    Groups samples by prompt_id, splits safely into train/test,
    and returns X_train, y_train, X_test, y_test.
    """

    unique_ids = sorted(set(curr_labels))

    X_train_list = []
    X_test_list = []
    y_train_list = []
    y_test_list = []

    for pid in unique_ids:

        # get samples for this prompt id
        mask = (curr_labels == pid)
        X_pid = curr_context_level_hs[mask]
        y_pid = curr_labels[mask]

        total = len(X_pid)
        train_n, test_n = safe_split(total, train_ratio)

        # split
        X_train_list.append(X_pid[:train_n])
        y_train_list.append(y_pid[:train_n])

        X_test_list.append(X_pid[train_n:])
        y_test_list.append(y_pid[train_n:])

    # concatenate all prompt-id blocks
    X_train = np.concatenate(X_train_list, axis=0)
    y_train = np.concatenate(y_train_list, axis=0)
    X_test  = np.concatenate(X_test_list, axis=0)
    y_test  = np.concatenate(y_test_list, axis=0)

    # return cp.array(X_train), cp.array(y_train), cp.array(X_test), cp.array(y_test)
    return X_train, y_train, X_test, y_test

# %%
# np.array(hidden_states_by_cl[f"cl_2"]).shape

# %%
# print(np.array(curr_labels[f"cl_2"]).shape)

# %%
# with open("results-test2.csv", "w+", newline='') as csvfile:
    #     csv_writer = csv.writer(csvfile, delimiter=',')
    #     header = ['Layer', 'Context_Level', 'Train_Accuracy', 'Test_Accuracy']
    #     prompt_headers = []
    #     for i in range(1, 11):
    #         prompt_headers.extend([f"Prompt_{i}_Train_Accuracy", f"Prompt_{i}_Test_Accuracy"])
    
    #     header.extend(prompt_headers)
    #     csv_writer.writerow(header)
for layer in layers:
    hidden_states_by_cl = {f"cl_{cl+2}": [] for cl in context_levels}
    curr_labels = {f"cl_{cl+2}": [] for cl in context_levels}
    
    for prompt_id in range(1, NUM_PROMPTS + 1):
        with np.load(f'../../../llamatales-xgboost-ii/hidden_states/prompt_{prompt_id}.npz') as loaded_data:
    
            for i in tqdm(range(1000)):
                hs = loaded_data[f"arr_{i}"]  # load once
    
                for context_level in context_levels:
                    if context_level >= hs.shape[0]:
                        continue
    
                    key = f"cl_{context_level + 2}"
    
                    hidden_states_by_cl[key].append(
                        hs[context_level][layer][0].astype("float32")
                    )
                    curr_labels[key].append(prompt_id - 1)
    
    for context_level in context_levels:
        print(f"Optimizing Layer {layer} at Context Level {context_level + 2}")
        cl_hs_array = hidden_states_by_cl[f"cl_{context_level + 2}"]
        curr_label_set = curr_labels[f"cl_{context_level + 2}"]
        # print(cl_hs_array[0].shape)
        # print(cl_hs_array[-1].shape)
        #1x512
    
        print(np.array(cl_hs_array).shape)
        for hs in range(len(cl_hs_array)):
            cl_hs_array[hs] = cl_hs_array[hs].flatten()
    
        curr_context_level_hs = np.array(cl_hs_array)
        print(curr_context_level_hs.shape)
    
        curr_label_set = np.array(curr_label_set)
    
        unique_ids = sorted(set(curr_label_set))
    
        if(len(unique_ids) < 10): break
        
        X_train, y_train, X_test, y_test = build_dataset(curr_context_level_hs, curr_label_set)
    
        X_train_opt, X_valid, y_train_opt, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state=42)
    
        #split into train and test and see how many samples of each class are in the test set (might explain 0.0 acc performance in test set).
        print(pd.Series(y_train).value_counts())
        print(pd.Series(y_test).value_counts())
        print(pd.Series(y_train_opt).value_counts())
        print(pd.Series(y_valid).value_counts())
    
        print("Train Data Shape: ", X_train.shape)
        print("Test Data Shape: ", X_test.shape)
        print("Optimizer Train Data Shape: ", X_train_opt.shape)
    
        X_train = cp.array(X_train)
        y_train = cp.array(y_train)
        X_test = cp.array(X_test)
        y_test = cp.array(y_test)
    
        X_train_opt = cp.array(X_train_opt)
        y_train_opt = cp.array(y_train_opt)
        X_valid = cp.array(X_valid)
        y_valid = cp.array(y_valid)
    
        #Test 1
        # classifier = XGBClassifier(max_depth = 3, 
        #                            reg_alpha = 10, 
        #                            reg_lambda = 10, 
        #                            gamma = 10, 
        #                            subsample = 0.75,
        #                            colsample_bytree = 0.75,
        #                            eta = 0.01,
        #                            n_estimators = 500,
        #                            # min_child_weight = 20,
        #                            seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids), tree_method='hist', device='cuda')
    
        #Test 2
        classifier = XGBClassifier(max_depth = 6, 
                                   reg_alpha = 10, 
                                   reg_lambda = 10, 
                                   gamma = 10, 
                                   subsample = 0.75,
                                   colsample_bytree = 0.75,
                                   eta = 0.01,
                                   n_estimators = 500,
                                   # min_child_weight = 20,
                                   seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids), tree_method='hist', device='cuda')
        
        classifier.fit(X_train, y_train)
        preds_train = classifier.predict(X_train)
        preds = classifier.predict(X_test)
    
        train_accuracy = np.mean(cp.array(preds_train) == y_train)
        accuracy = np.mean(cp.array(preds) == y_test)
    
        print(f"Train Accuracy: {train_accuracy}")
        print(f"Test Accuracy: {accuracy}")
    
        prompt_accs = []
    
        for i in range(10):
            mask = y_test == i
            prompt_test = y_test[mask]
            prompt_preds = cp.array(preds)[mask]
            prompt_test_acc = np.mean(prompt_preds == prompt_test)
    
            mask_train = y_train == i
            prompt_train = y_train[mask_train]
            prompt_preds_train = cp.array(preds_train)[mask_train]
            prompt_train_acc = np.mean(prompt_preds_train == prompt_train)
    
            print(f"Prompt {i + 1} Train Accuracy: {prompt_train_acc}")
            print(f"Prompt {i + 1} Test Accuracy: {prompt_test_acc}")
    
            prompt_accs.append(prompt_train_acc)
            prompt_accs.append(prompt_test_acc)
    
        
        with open("results-test2.csv", "a+", newline='') as csvfile:
            csv_writer = csv.writer(csvfile, delimiter=',')
            values = [layer, context_level + 2, train_accuracy, accuracy]
            values.extend(prompt_accs)
            csv_writer.writerow(values)
                
    
    
        del classifier, X_train, y_train, X_test, y_test, preds
    
        # XGBoost cleanup
        try:
            booster = classifier.get_booster()
            del booster
        except:
            pass
        
        # CuPy cleanup
        cp.get_default_memory_pool().free_all_blocks()
        cp.get_default_pinned_memory_pool().free_all_blocks()
        
        gc.collect()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.84it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:51<00:00, 19.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:01<00:00, 16.32it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:05<00:00, 15.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:02<00:00, 16.12it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:01<00:00, 16.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:00<00:00, 16.47it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.40it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.72it/s]
# Optimizing Layer 3 at Context Level 25
# (10000, 1, 512)
# (10000, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 6    800
# 7    800
# 8    800
# 9    800
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 6    654
# 4    653
# 2    642
# 9    642
# 3    639
# 5    639
# 8    635
# 1    634
# 7    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    166
# 8    165
# 3    161
# 5    161
# 2    158
# 9    158
# 4    147
# 6    146
# Name: count, dtype: int64
# Train Data Shape:  (8000, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6400, 512)
# Train Accuracy: 0.52625
# Test Accuracy: 0.387
# Prompt 1 Train Accuracy: 0.50375
# Prompt 1 Test Accuracy: 0.315
# Prompt 2 Train Accuracy: 0.375
# Prompt 2 Test Accuracy: 0.275
# Prompt 3 Train Accuracy: 0.79
# Prompt 3 Test Accuracy: 0.66
# Prompt 4 Train Accuracy: 0.145
# Prompt 4 Test Accuracy: 0.1
# Prompt 5 Train Accuracy: 0.67625
# Prompt 5 Test Accuracy: 0.495
# Prompt 6 Train Accuracy: 0.48875
# Prompt 6 Test Accuracy: 0.335
# Prompt 7 Train Accuracy: 0.52
# Prompt 7 Test Accuracy: 0.355
# Prompt 8 Train Accuracy: 0.4275
# Prompt 8 Test Accuracy: 0.28
# Prompt 9 Train Accuracy: 0.5475
# Prompt 9 Test Accuracy: 0.395
# Prompt 10 Train Accuracy: 0.78875
# Prompt 10 Test Accuracy: 0.66
# Optimizing Layer 3 at Context Level 50
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.3352919114889361
# Test Accuracy: 0.227
# Prompt 1 Train Accuracy: 0.165
# Prompt 1 Test Accuracy: 0.085
# Prompt 2 Train Accuracy: 0.09375
# Prompt 2 Test Accuracy: 0.08
# Prompt 3 Train Accuracy: 0.67125
# Prompt 3 Test Accuracy: 0.535
# Prompt 4 Train Accuracy: 0.01875
# Prompt 4 Test Accuracy: 0.025
# Prompt 5 Train Accuracy: 0.585
# Prompt 5 Test Accuracy: 0.365
# Prompt 6 Train Accuracy: 0.35875
# Prompt 6 Test Accuracy: 0.215
# Prompt 7 Train Accuracy: 0.10888610763454318
# Prompt 7 Test Accuracy: 0.045
# Prompt 8 Train Accuracy: 0.34375
# Prompt 8 Test Accuracy: 0.215
# Prompt 9 Train Accuracy: 0.52375
# Prompt 9 Test Accuracy: 0.37
# Prompt 10 Train Accuracy: 0.48375
# Prompt 10 Test Accuracy: 0.335
# Optimizing Layer 3 at Context Level 75
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.27428428553569195
# Test Accuracy: 0.1825
# Prompt 1 Train Accuracy: 0.1625
# Prompt 1 Test Accuracy: 0.09
# Prompt 2 Train Accuracy: 0.005
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.6225
# Prompt 3 Test Accuracy: 0.43
# Prompt 4 Train Accuracy: 0.0125
# Prompt 4 Test Accuracy: 0.005
# Prompt 5 Train Accuracy: 0.53
# Prompt 5 Test Accuracy: 0.4
# Prompt 6 Train Accuracy: 0.24125
# Prompt 6 Test Accuracy: 0.165
# Prompt 7 Train Accuracy: 0.3429286608260325
# Prompt 7 Test Accuracy: 0.225
# Prompt 8 Train Accuracy: 0.21375
# Prompt 8 Test Accuracy: 0.175
# Prompt 9 Train Accuracy: 0.32375
# Prompt 9 Test Accuracy: 0.16
# Prompt 10 Train Accuracy: 0.28875
# Prompt 10 Test Accuracy: 0.175
# Optimizing Layer 3 at Context Level 100
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.24590573821727715
# Test Accuracy: 0.1825
# Prompt 1 Train Accuracy: 0.13625
# Prompt 1 Test Accuracy: 0.075
# Prompt 2 Train Accuracy: 0.0275
# Prompt 2 Test Accuracy: 0.03
# Prompt 3 Train Accuracy: 0.63875
# Prompt 3 Test Accuracy: 0.46
# Prompt 4 Train Accuracy: 0.035
# Prompt 4 Test Accuracy: 0.025
# Prompt 5 Train Accuracy: 0.18125
# Prompt 5 Test Accuracy: 0.125
# Prompt 6 Train Accuracy: 0.265
# Prompt 6 Test Accuracy: 0.21
# Prompt 7 Train Accuracy: 0.1739674593241552
# Prompt 7 Test Accuracy: 0.12
# Prompt 8 Train Accuracy: 0.23625
# Prompt 8 Test Accuracy: 0.185
# Prompt 9 Train Accuracy: 0.455
# Prompt 9 Test Accuracy: 0.365
# Prompt 10 Train Accuracy: 0.31
# Prompt 10 Test Accuracy: 0.23
# Optimizing Layer 3 at Context Level 125
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.2194024253031629
# Test Accuracy: 0.162
# Prompt 1 Train Accuracy: 0.0425
# Prompt 1 Test Accuracy: 0.025
# Prompt 2 Train Accuracy: 0.02125
# Prompt 2 Test Accuracy: 0.02
# Prompt 3 Train Accuracy: 0.53625
# Prompt 3 Test Accuracy: 0.41
# Prompt 4 Train Accuracy: 0.005
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.39
# Prompt 5 Test Accuracy: 0.265
# Prompt 6 Train Accuracy: 0.2125
# Prompt 6 Test Accuracy: 0.155
# Prompt 7 Train Accuracy: 0.16896120150187735
# Prompt 7 Test Accuracy: 0.14
# Prompt 8 Train Accuracy: 0.13875
# Prompt 8 Test Accuracy: 0.095
# Prompt 9 Train Accuracy: 0.31625
# Prompt 9 Test Accuracy: 0.265
# Prompt 10 Train Accuracy: 0.3625
# Prompt 10 Test Accuracy: 0.245
# Optimizing Layer 3 at Context Level 150
# (9984, 1, 512)
# (9984, 512)
# 1    800
# 2    800
# 4    800
# 8    800
# 0    799
# 9    799
# 5    798
# 3    797
# 6    796
# 7    796
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 7    200
# 8    200
# 9    200
# 6    199
# Name: count, dtype: int64
# 6    656
# 7    651
# 3    641
# 9    641
# 4    641
# 2    638
# 5    637
# 1    633
# 0    627
# 8    623
# Name: count, dtype: int64
# 8    177
# 0    172
# 1    167
# 2    162
# 5    161
# 4    159
# 9    158
# 3    156
# 7    145
# 6    140
# Name: count, dtype: int64
# Train Data Shape:  (7985, 512)
# Test Data Shape:  (1999, 512)
# Optimizer Train Data Shape:  (6388, 512)
# Train Accuracy: 0.24946775203506574
# Test Accuracy: 0.17408704352176088
# Prompt 1 Train Accuracy: 0.24030037546933666
# Prompt 1 Test Accuracy: 0.225
# Prompt 2 Train Accuracy: 0.015
# Prompt 2 Test Accuracy: 0.01
# Prompt 3 Train Accuracy: 0.59625
# Prompt 3 Test Accuracy: 0.45
# Prompt 4 Train Accuracy: 0.18193224592220827
# Prompt 4 Test Accuracy: 0.1
# Prompt 5 Train Accuracy: 0.265
# Prompt 5 Test Accuracy: 0.18
# Prompt 6 Train Accuracy: 0.39097744360902253
# Prompt 6 Test Accuracy: 0.22
# Prompt 7 Train Accuracy: 0.3203517587939699
# Prompt 7 Test Accuracy: 0.19597989949748743
# Prompt 8 Train Accuracy: 0.048994974874371856
# Prompt 8 Test Accuracy: 0.025
# Prompt 9 Train Accuracy: 0.12125
# Prompt 9 Test Accuracy: 0.12
# Prompt 10 Train Accuracy: 0.3141426783479349
# Prompt 10 Test Accuracy: 0.215
# Optimizing Layer 3 at Context Level 175
# (9835, 1, 512)
# (9835, 512)
# 9    796
# 2    794
# 8    794
# 4    792
# 0    790
# 6    782
# 5    780
# 1    779
# 7    779
# 3    777
# Name: count, dtype: int64
# 9    200
# 2    199
# 4    199
# 8    199
# 0    198
# 5    196
# 6    196
# 1    195
# 3    195
# 7    195
# Name: count, dtype: int64
# 9    645
# 6    641
# 4    637
# 8    635
# 2    635
# 7    625
# 3    622
# 5    622
# 0    617
# 1    611
# Name: count, dtype: int64
# 0    173
# 1    168
# 8    159
# 2    159
# 5    158
# 3    155
# 4    155
# 7    154
# 9    151
# 6    141
# Name: count, dtype: int64
# Train Data Shape:  (7863, 512)
# Test Data Shape:  (1972, 512)
# Optimizer Train Data Shape:  (6290, 512)
# Train Accuracy: 0.2439272542286659
# Test Accuracy: 0.16024340770791076
# Prompt 1 Train Accuracy: 0.017721518987341773
# Prompt 1 Test Accuracy: 0.015151515151515152
# Prompt 2 Train Accuracy: 0.0025673940949935813
# Prompt 2 Test Accuracy: 0.005128205128205128
# Prompt 3 Train Accuracy: 0.5730478589420654
# Prompt 3 Test Accuracy: 0.40703517587939697
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.380050505050505
# Prompt 5 Test Accuracy: 0.24120603015075376
# Prompt 6 Train Accuracy: 0.25256410256410255
# Prompt 6 Test Accuracy: 0.19387755102040816
# Prompt 7 Train Accuracy: 0.34398976982097185
# Prompt 7 Test Accuracy: 0.17346938775510204
# Prompt 8 Train Accuracy: 0.0821566110397946
# Prompt 8 Test Accuracy: 0.035897435897435895
# Prompt 9 Train Accuracy: 0.336272040302267
# Prompt 9 Test Accuracy: 0.21105527638190955
# Prompt 10 Train Accuracy: 0.43844221105527637
# Prompt 10 Test Accuracy: 0.31
# Optimizing Layer 3 at Context Level 200
# (9361, 1, 512)
# (9361, 512)
# 8    779
# 2    777
# 9    776
# 4    764
# 0    755
# 6    732
# 7    732
# 5    728
# 1    724
# 3    718
# Name: count, dtype: int64
# 2    195
# 8    195
# 9    195
# 4    192
# 0    189
# 7    184
# 6    183
# 5    182
# 1    181
# 3    180
# Name: count, dtype: int64
# 9    632
# 8    628
# 4    620
# 2    605
# 0    591
# 6    588
# 7    584
# 3    584
# 1    581
# 5    575
# Name: count, dtype: int64
# 2    172
# 0    164
# 5    153
# 8    151
# 7    148
# 9    144
# 4    144
# 6    144
# 1    143
# 3    134
# Name: count, dtype: int64
# Train Data Shape:  (7485, 512)
# Test Data Shape:  (1876, 512)
# Optimizer Train Data Shape:  (5988, 512)
# Train Accuracy: 0.2141616566466266
# Test Accuracy: 0.1695095948827292
# Prompt 1 Train Accuracy: 0.04105960264900662
# Prompt 1 Test Accuracy: 0.037037037037037035
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.6396396396396397
# Prompt 3 Test Accuracy: 0.5692307692307692
# Prompt 4 Train Accuracy: 0.008356545961002786
# Prompt 4 Test Accuracy: 0.005555555555555556
# Prompt 5 Train Accuracy: 0.25
# Prompt 5 Test Accuracy: 0.19270833333333334
# Prompt 6 Train Accuracy: 0.20192307692307693
# Prompt 6 Test Accuracy: 0.09340659340659341
# Prompt 7 Train Accuracy: 0.296448087431694
# Prompt 7 Test Accuracy: 0.20218579234972678
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.005434782608695652
# Prompt 9 Train Accuracy: 0.4030808729139923
# Prompt 9 Test Accuracy: 0.36923076923076925
# Prompt 10 Train Accuracy: 0.25773195876288657
# Prompt 10 Test Accuracy: 0.1794871794871795
# Optimizing Layer 3 at Context Level 225
# (8394, 1, 512)
# (8394, 512)
# 9    738
# 2    720
# 8    709
# 4    692
# 0    675
# 7    652
# 1    636
# 6    635
# 5    630
# 3    624
# Name: count, dtype: int64
# 9    185
# 2    180
# 8    178
# 4    174
# 0    169
# 7    164
# 1    160
# 6    159
# 5    158
# 3    156
# Name: count, dtype: int64
# 9    604
# 8    563
# 2    562
# 4    548
# 7    524
# 0    522
# 1    520
# 3    515
# 6    509
# 5    501
# Name: count, dtype: int64
# 2    158
# 0    153
# 8    146
# 4    144
# 9    134
# 5    129
# 7    128
# 6    126
# 1    116
# 3    109
# Name: count, dtype: int64
# Train Data Shape:  (6711, 512)
# Test Data Shape:  (1683, 512)
# Optimizer Train Data Shape:  (5368, 512)
# Train Accuracy: 0.19669199821189093
# Test Accuracy: 0.14795008912655971
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.6555555555555556
# Prompt 3 Test Accuracy: 0.5
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.30057803468208094
# Prompt 5 Test Accuracy: 0.22988505747126436
# Prompt 6 Train Accuracy: 0.09365079365079365
# Prompt 6 Test Accuracy: 0.04430379746835443
# Prompt 7 Train Accuracy: 0.08031496062992126
# Prompt 7 Test Accuracy: 0.0440251572327044
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.18758815232722145
# Prompt 9 Test Accuracy: 0.16292134831460675
# Prompt 10 Train Accuracy: 0.537940379403794
# Prompt 10 Test Accuracy: 0.41081081081081083
# Optimizing Layer 3 at Context Level 250
# (6898, 1, 512)
# (6898, 512)
# 9    648
# 8    624
# 2    621
# 4    581
# 0    548
# 7    522
# 6    501
# 1    495
# 3    492
# 5    483
# Name: count, dtype: int64
# 9    162
# 2    156
# 8    156
# 4    146
# 0    138
# 7    131
# 6    126
# 1    124
# 3    123
# 5    121
# Name: count, dtype: int64
# 9    533
# 8    487
# 2    478
# 4    454
# 7    424
# 0    420
# 6    417
# 3    408
# 1    398
# 5    393
# Name: count, dtype: int64
# 2    143
# 8    137
# 0    128
# 4    127
# 9    115
# 7     98
# 1     97
# 5     90
# 6     84
# 3     84
# Name: count, dtype: int64
# Train Data Shape:  (5515, 512)
# Test Data Shape:  (1383, 512)
# Optimizer Train Data Shape:  (4412, 512)
# Train Accuracy: 0.17842248413417952
# Test Accuracy: 0.14389009399855388
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.5748792270531401
# Prompt 3 Test Accuracy: 0.41025641025641024
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.2532051282051282
# Prompt 9 Test Accuracy: 0.16666666666666666
# Prompt 10 Train Accuracy: 0.7237654320987654
# Prompt 10 Test Accuracy: 0.6728395061728395
# Optimizing Layer 3 at Context Level 275
# (5137, 1, 512)
# (5137, 512)
# 9    508
# 8    504
# 2    500
# 4    452
# 0    408
# 7    376
# 6    347
# 1    344
# 5    336
# 3    328
# Name: count, dtype: int64
# 9    128
# 8    127
# 2    126
# 4    114
# 0    103
# 7     95
# 1     87
# 6     87
# 5     85
# 3     82
# Name: count, dtype: int64
# 9    414
# 8    406
# 2    393
# 4    357
# 0    307
# 7    307
# 1    282
# 5    273
# 6    272
# 3    271
# Name: count, dtype: int64
# 2    107
# 0    101
# 8     98
# 4     95
# 9     94
# 6     75
# 7     69
# 5     63
# 1     62
# 3     57
# Name: count, dtype: int64
# Train Data Shape:  (4103, 512)
# Test Data Shape:  (1034, 512)
# Optimizer Train Data Shape:  (3282, 512)
# Train Accuracy: 0.17962466487935658
# Test Accuracy: 0.14119922630560927
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.54
# Prompt 3 Test Accuracy: 0.4444444444444444
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.3373015873015873
# Prompt 9 Test Accuracy: 0.25984251968503935
# Prompt 10 Train Accuracy: 0.5846456692913385
# Prompt 10 Test Accuracy: 0.4453125
# Optimizing Layer 3 at Context Level 300
# (3342, 1, 512)
# (3342, 512)
# 9    370
# 8    365
# 2    343
# 4    292
# 0    256
# 7    230
# 6    217
# 1    211
# 5    206
# 3    180
# Name: count, dtype: int64
# 9    93
# 8    92
# 2    86
# 4    73
# 0    64
# 7    58
# 6    55
# 1    53
# 5    52
# 3    46
# Name: count, dtype: int64
# 9    300
# 8    288
# 2    276
# 4    228
# 0    204
# 6    183
# 7    178
# 5    172
# 1    165
# 3    142
# Name: count, dtype: int64
# 8    77
# 9    70
# 2    67
# 4    64
# 0    52
# 7    52
# 1    46
# 3    38
# 5    34
# 6    34
# Name: count, dtype: int64
# Train Data Shape:  (2670, 512)
# Test Data Shape:  (672, 512)
# Optimizer Train Data Shape:  (2136, 512)
# Train Accuracy: 0.16367041198501872
# Test Accuracy: 0.15625
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.7123287671232876
# Prompt 9 Test Accuracy: 0.5543478260869565
# Prompt 10 Train Accuracy: 0.4783783783783784
# Prompt 10 Test Accuracy: 0.5806451612903226
# Optimizing Layer 3 at Context Level 325
# (1890, 1, 512)
# (1890, 512)
# 9    234
# 8    224
# 2    202
# 4    175
# 0    144
# 7    114
# 6    111
# 1    109
# 5    100
# 3     95
# Name: count, dtype: int64
# 9    59
# 8    57
# 2    51
# 4    44
# 0    36
# 7    29
# 1    28
# 6    28
# 5    26
# 3    24
# Name: count, dtype: int64
# 9    191
# 8    175
# 2    159
# 4    137
# 0    116
# 6     90
# 1     90
# 7     87
# 5     84
# 3     77
# Name: count, dtype: int64
# 8    49
# 2    43
# 9    43
# 4    38
# 0    28
# 7    27
# 6    21
# 1    19
# 3    18
# 5    16
# Name: count, dtype: int64
# Train Data Shape:  (1508, 512)
# Test Data Shape:  (382, 512)
# Optimizer Train Data Shape:  (1206, 512)
# Train Accuracy: 0.15517241379310345
# Test Accuracy: 0.1544502617801047
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 3 at Context Level 350
# (985, 1, 512)
# (985, 512)
# 9    141
# 8    124
# 2    112
# 4     96
# 0     74
# 7     58
# 1     51
# 6     46
# 3     44
# 5     40
# Name: count, dtype: int64
# 9    36
# 8    31
# 2    28
# 4    24
# 0    19
# 7    15
# 1    13
# 6    12
# 3    11
# 5    10
# Name: count, dtype: int64
# 9    111
# 8     97
# 2     95
# 4     71
# 0     58
# 7     46
# 3     40
# 1     39
# 6     36
# 5     35
# Name: count, dtype: int64
# 9    30
# 8    27
# 4    25
# 2    17
# 0    16
# 7    12
# 1    12
# 6    10
# 5     5
# 3     4
# Name: count, dtype: int64
# Train Data Shape:  (786, 512)
# Test Data Shape:  (199, 512)
# Optimizer Train Data Shape:  (628, 512)
# Train Accuracy: 0.17938931297709923
# Test Accuracy: 0.18090452261306533
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 3 at Context Level 375
# (474, 1, 512)
# (474, 512)
# 9    72
# 8    61
# 2    54
# 0    37
# 4    37
# 7    29
# 1    24
# 3    23
# 5    19
# 6    18
# Name: count, dtype: int64
# 9    19
# 8    16
# 2    14
# 0    10
# 4    10
# 7     8
# 1     7
# 3     6
# 5     5
# 6     5
# Name: count, dtype: int64
# 9    59
# 8    53
# 2    40
# 4    33
# 0    28
# 7    20
# 3    18
# 1    17
# 5    16
# 6    15
# Name: count, dtype: int64
# 2    14
# 9    13
# 0     9
# 7     9
# 8     8
# 1     7
# 3     5
# 4     4
# 5     3
# 6     3
# Name: count, dtype: int64
# Train Data Shape:  (374, 512)
# Test Data Shape:  (100, 512)
# Optimizer Train Data Shape:  (299, 512)
# Train Accuracy: 0.1925133689839572
# Test Accuracy: 0.19
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 3 at Context Level 400
# (192, 1, 512)
# (192, 512)
# 8    33
# 9    31
# 2    20
# 4    16
# 0    11
# 1    11
# 7    10
# 5     7
# 3     6
# 6     5
# Name: count, dtype: int64
# 8    9
# 9    8
# 2    6
# 4    4
# 0    3
# 1    3
# 7    3
# 3    2
# 5    2
# 6    2
# Name: count, dtype: int64
# 8    29
# 9    24
# 2    15
# 4    14
# 0    10
# 1     8
# 7     7
# 3     5
# 5     4
# 6     4
# Name: count, dtype: int64
# 9    7
# 2    5
# 8    4
# 1    3
# 7    3
# 5    3
# 4    2
# 6    1
# 0    1
# 3    1
# Name: count, dtype: int64
# Train Data Shape:  (150, 512)
# Test Data Shape:  (42, 512)
# Optimizer Train Data Shape:  (120, 512)
# Train Accuracy: 0.22
# Test Accuracy: 0.21428571428571427
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 1.0
# Prompt 9 Test Accuracy: 1.0
# Prompt 10 Train Accuracy: 0.0
# Prompt 10 Test Accuracy: 0.0
# Optimizing Layer 3 at Context Level 425
# (73, 1, 512)
# (73, 512)
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:06<00:00, 14.97it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:03<00:00, 15.75it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:10<00:00, 14.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:03<00:00, 15.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.92it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:57<00:00, 17.26it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:01<00:00, 16.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.71it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:08<00:00, 14.63it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.48it/s]
# Optimizing Layer 4 at Context Level 25
# (10000, 1, 512)
# (10000, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 6    800
# 7    800
# 8    800
# 9    800
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 6    654
# 4    653
# 2    642
# 9    642
# 3    639
# 5    639
# 8    635
# 1    634
# 7    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    166
# 8    165
# 3    161
# 5    161
# 2    158
# 9    158
# 4    147
# 6    146
# Name: count, dtype: int64
# Train Data Shape:  (8000, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6400, 512)
# Train Accuracy: 0.612125
# Test Accuracy: 0.4595
# Prompt 1 Train Accuracy: 0.6225
# Prompt 1 Test Accuracy: 0.395
# Prompt 2 Train Accuracy: 0.50375
# Prompt 2 Test Accuracy: 0.345
# Prompt 3 Train Accuracy: 0.785
# Prompt 3 Test Accuracy: 0.645
# Prompt 4 Train Accuracy: 0.2225
# Prompt 4 Test Accuracy: 0.125
# Prompt 5 Train Accuracy: 0.72
# Prompt 5 Test Accuracy: 0.515
# Prompt 6 Train Accuracy: 0.60375
# Prompt 6 Test Accuracy: 0.435
# Prompt 7 Train Accuracy: 0.525
# Prompt 7 Test Accuracy: 0.385
# Prompt 8 Train Accuracy: 0.63375
# Prompt 8 Test Accuracy: 0.475
# Prompt 9 Train Accuracy: 0.7125
# Prompt 9 Test Accuracy: 0.59
# Prompt 10 Train Accuracy: 0.7925
# Prompt 10 Test Accuracy: 0.685
# Optimizing Layer 4 at Context Level 50
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.40055006875859483
# Test Accuracy: 0.2685
# Prompt 1 Train Accuracy: 0.23625
# Prompt 1 Test Accuracy: 0.145
# Prompt 2 Train Accuracy: 0.1225
# Prompt 2 Test Accuracy: 0.085
# Prompt 3 Train Accuracy: 0.68375
# Prompt 3 Test Accuracy: 0.595
# Prompt 4 Train Accuracy: 0.0475
# Prompt 4 Test Accuracy: 0.015
# Prompt 5 Train Accuracy: 0.5425
# Prompt 5 Test Accuracy: 0.345
# Prompt 6 Train Accuracy: 0.525
# Prompt 6 Test Accuracy: 0.34
# Prompt 7 Train Accuracy: 0.2065081351689612
# Prompt 7 Test Accuracy: 0.1
# Prompt 8 Train Accuracy: 0.43
# Prompt 8 Test Accuracy: 0.255
# Prompt 9 Train Accuracy: 0.625
# Prompt 9 Test Accuracy: 0.42
# Prompt 10 Train Accuracy: 0.58625
# Prompt 10 Test Accuracy: 0.385
# Optimizing Layer 4 at Context Level 75
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.3365420677584698
# Test Accuracy: 0.2375
# Prompt 1 Train Accuracy: 0.22875
# Prompt 1 Test Accuracy: 0.15
# Prompt 2 Train Accuracy: 0.1125
# Prompt 2 Test Accuracy: 0.09
# Prompt 3 Train Accuracy: 0.70875
# Prompt 3 Test Accuracy: 0.535
# Prompt 4 Train Accuracy: 0.01
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.50875
# Prompt 5 Test Accuracy: 0.39
# Prompt 6 Train Accuracy: 0.2575
# Prompt 6 Test Accuracy: 0.17
# Prompt 7 Train Accuracy: 0.2978723404255319
# Prompt 7 Test Accuracy: 0.18
# Prompt 8 Train Accuracy: 0.21
# Prompt 8 Test Accuracy: 0.145
# Prompt 9 Train Accuracy: 0.52125
# Prompt 9 Test Accuracy: 0.355
# Prompt 10 Train Accuracy: 0.51
# Prompt 10 Test Accuracy: 0.36
# Optimizing Layer 4 at Context Level 100
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.3119139892486561
# Test Accuracy: 0.221
# Prompt 1 Train Accuracy: 0.235
# Prompt 1 Test Accuracy: 0.175
# Prompt 2 Train Accuracy: 0.05
# Prompt 2 Test Accuracy: 0.025
# Prompt 3 Train Accuracy: 0.675
# Prompt 3 Test Accuracy: 0.52
# Prompt 4 Train Accuracy: 0.14125
# Prompt 4 Test Accuracy: 0.09
# Prompt 5 Train Accuracy: 0.37375
# Prompt 5 Test Accuracy: 0.19
# Prompt 6 Train Accuracy: 0.19
# Prompt 6 Test Accuracy: 0.13
# Prompt 7 Train Accuracy: 0.17647058823529413
# Prompt 7 Test Accuracy: 0.095
# Prompt 8 Train Accuracy: 0.2225
# Prompt 8 Test Accuracy: 0.225
# Prompt 9 Train Accuracy: 0.56625
# Prompt 9 Test Accuracy: 0.43
# Prompt 10 Train Accuracy: 0.48875
# Prompt 10 Test Accuracy: 0.33
# Optimizing Layer 4 at Context Level 125
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.25715714464308037
# Test Accuracy: 0.1745
# Prompt 1 Train Accuracy: 0.07625
# Prompt 1 Test Accuracy: 0.03
# Prompt 2 Train Accuracy: 0.1325
# Prompt 2 Test Accuracy: 0.08
# Prompt 3 Train Accuracy: 0.68375
# Prompt 3 Test Accuracy: 0.44
# Prompt 4 Train Accuracy: 0.025
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.24625
# Prompt 5 Test Accuracy: 0.16
# Prompt 6 Train Accuracy: 0.32875
# Prompt 6 Test Accuracy: 0.245
# Prompt 7 Train Accuracy: 0.14267834793491865
# Prompt 7 Test Accuracy: 0.11
# Prompt 8 Train Accuracy: 0.105
# Prompt 8 Test Accuracy: 0.085
# Prompt 9 Train Accuracy: 0.40125
# Prompt 9 Test Accuracy: 0.33
# Prompt 10 Train Accuracy: 0.43
# Prompt 10 Test Accuracy: 0.265
# Optimizing Layer 4 at Context Level 150
# (9984, 1, 512)
# (9984, 512)
# 1    800
# 2    800
# 4    800
# 8    800
# 0    799
# 9    799
# 5    798
# 3    797
# 6    796
# 7    796
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 7    200
# 8    200
# 9    200
# 6    199
# Name: count, dtype: int64
# 6    656
# 7    651
# 3    641
# 9    641
# 4    641
# 2    638
# 5    637
# 1    633
# 0    627
# 8    623
# Name: count, dtype: int64
# 8    177
# 0    172
# 1    167
# 2    162
# 5    161
# 4    159
# 9    158
# 3    156
# 7    145
# 6    140
# Name: count, dtype: int64
# Train Data Shape:  (7985, 512)
# Test Data Shape:  (1999, 512)
# Optimizer Train Data Shape:  (6388, 512)
# Train Accuracy: 0.278146524733876
# Test Accuracy: 0.19809904952476237
# Prompt 1 Train Accuracy: 0.2127659574468085
# Prompt 1 Test Accuracy: 0.18
# Prompt 2 Train Accuracy: 0.09375
# Prompt 2 Test Accuracy: 0.08
# Prompt 3 Train Accuracy: 0.63625
# Prompt 3 Test Accuracy: 0.49
# Prompt 4 Train Accuracy: 0.01631116687578419
# Prompt 4 Test Accuracy: 0.01
# Prompt 5 Train Accuracy: 0.29875
# Prompt 5 Test Accuracy: 0.2
# Prompt 6 Train Accuracy: 0.41353383458646614
# Prompt 6 Test Accuracy: 0.265
# Prompt 7 Train Accuracy: 0.34296482412060303
# Prompt 7 Test Accuracy: 0.23618090452261306
# Prompt 8 Train Accuracy: 0.05527638190954774
# Prompt 8 Test Accuracy: 0.03
# Prompt 9 Train Accuracy: 0.295
# Prompt 9 Test Accuracy: 0.18
# Prompt 10 Train Accuracy: 0.41551939924906134
# Prompt 10 Test Accuracy: 0.31
# Optimizing Layer 4 at Context Level 175
# (9835, 1, 512)
# (9835, 512)
# 9    796
# 2    794
# 8    794
# 4    792
# 0    790
# 6    782
# 5    780
# 1    779
# 7    779
# 3    777
# Name: count, dtype: int64
# 9    200
# 2    199
# 4    199
# 8    199
# 0    198
# 5    196
# 6    196
# 1    195
# 3    195
# 7    195
# Name: count, dtype: int64
# 9    645
# 6    641
# 4    637
# 8    635
# 2    635
# 7    625
# 3    622
# 5    622
# 0    617
# 1    611
# Name: count, dtype: int64
# 0    173
# 1    168
# 8    159
# 2    159
# 5    158
# 3    155
# 4    155
# 7    154
# 9    151
# 6    141
# Name: count, dtype: int64
# Train Data Shape:  (7863, 512)
# Test Data Shape:  (1972, 512)
# Optimizer Train Data Shape:  (6290, 512)
# Train Accuracy: 0.2612234516088007
# Test Accuracy: 0.17342799188640973
# Prompt 1 Train Accuracy: 0.05189873417721519
# Prompt 1 Test Accuracy: 0.025252525252525252
# Prompt 2 Train Accuracy: 0.043645699614890884
# Prompt 2 Test Accuracy: 0.035897435897435895
# Prompt 3 Train Accuracy: 0.6410579345088161
# Prompt 3 Test Accuracy: 0.4824120603015075
# Prompt 4 Train Accuracy: 0.02059202059202059
# Prompt 4 Test Accuracy: 0.005128205128205128
# Prompt 5 Train Accuracy: 0.2297979797979798
# Prompt 5 Test Accuracy: 0.1507537688442211
# Prompt 6 Train Accuracy: 0.35
# Prompt 6 Test Accuracy: 0.20918367346938777
# Prompt 7 Train Accuracy: 0.35421994884910485
# Prompt 7 Test Accuracy: 0.19387755102040816
# Prompt 8 Train Accuracy: 0.13093709884467267
# Prompt 8 Test Accuracy: 0.07692307692307693
# Prompt 9 Train Accuracy: 0.336272040302267
# Prompt 9 Test Accuracy: 0.2562814070351759
# Prompt 10 Train Accuracy: 0.4434673366834171
# Prompt 10 Test Accuracy: 0.29
# Optimizing Layer 4 at Context Level 200
# (9361, 1, 512)
# (9361, 512)
# 8    779
# 2    777
# 9    776
# 4    764
# 0    755
# 6    732
# 7    732
# 5    728
# 1    724
# 3    718
# Name: count, dtype: int64
# 2    195
# 8    195
# 9    195
# 4    192
# 0    189
# 7    184
# 6    183
# 5    182
# 1    181
# 3    180
# Name: count, dtype: int64
# 9    632
# 8    628
# 4    620
# 2    605
# 0    591
# 6    588
# 7    584
# 3    584
# 1    581
# 5    575
# Name: count, dtype: int64
# 2    172
# 0    164
# 5    153
# 8    151
# 7    148
# 9    144
# 4    144
# 6    144
# 1    143
# 3    134
# Name: count, dtype: int64
# Train Data Shape:  (7485, 512)
# Test Data Shape:  (1876, 512)
# Optimizer Train Data Shape:  (5988, 512)
# Train Accuracy: 0.251436205744823
# Test Accuracy: 0.18443496801705758
# Prompt 1 Train Accuracy: 0.10198675496688742
# Prompt 1 Test Accuracy: 0.05291005291005291
# Prompt 2 Train Accuracy: 0.0027624309392265192
# Prompt 2 Test Accuracy: 0.0055248618784530384
# Prompt 3 Train Accuracy: 0.7065637065637066
# Prompt 3 Test Accuracy: 0.5384615384615384
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.22774869109947643
# Prompt 5 Test Accuracy: 0.203125
# Prompt 6 Train Accuracy: 0.29395604395604397
# Prompt 6 Test Accuracy: 0.15934065934065933
# Prompt 7 Train Accuracy: 0.25136612021857924
# Prompt 7 Test Accuracy: 0.15300546448087432
# Prompt 8 Train Accuracy: 0.028688524590163935
# Prompt 8 Test Accuracy: 0.03804347826086957
# Prompt 9 Train Accuracy: 0.44801026957637996
# Prompt 9 Test Accuracy: 0.39487179487179486
# Prompt 10 Train Accuracy: 0.4020618556701031
# Prompt 10 Test Accuracy: 0.2564102564102564
# Optimizing Layer 4 at Context Level 225
# (8394, 1, 512)
# (8394, 512)
# 9    738
# 2    720
# 8    709
# 4    692
# 0    675
# 7    652
# 1    636
# 6    635
# 5    630
# 3    624
# Name: count, dtype: int64
# 9    185
# 2    180
# 8    178
# 4    174
# 0    169
# 7    164
# 1    160
# 6    159
# 5    158
# 3    156
# Name: count, dtype: int64
# 9    604
# 8    563
# 2    562
# 4    548
# 7    524
# 0    522
# 1    520
# 3    515
# 6    509
# 5    501
# Name: count, dtype: int64
# 2    158
# 0    153
# 8    146
# 4    144
# 9    134
# 5    129
# 7    128
# 6    126
# 1    116
# 3    109
# Name: count, dtype: int64
# Train Data Shape:  (6711, 512)
# Test Data Shape:  (1683, 512)
# Optimizer Train Data Shape:  (5368, 512)
# Train Accuracy: 0.2136790344210997
# Test Accuracy: 0.16696375519904932
# Prompt 1 Train Accuracy: 0.023703703703703703
# Prompt 1 Test Accuracy: 0.03550295857988166
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.6930555555555555
# Prompt 3 Test Accuracy: 0.5444444444444444
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.26734104046242774
# Prompt 5 Test Accuracy: 0.16666666666666666
# Prompt 6 Train Accuracy: 0.05238095238095238
# Prompt 6 Test Accuracy: 0.02531645569620253
# Prompt 7 Train Accuracy: 0.09921259842519685
# Prompt 7 Test Accuracy: 0.05660377358490566
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.21015514809590974
# Prompt 9 Test Accuracy: 0.23595505617977527
# Prompt 10 Train Accuracy: 0.6626016260162602
# Prompt 10 Test Accuracy: 0.5027027027027027
# Optimizing Layer 4 at Context Level 250
# (6898, 1, 512)
# (6898, 512)
# 9    648
# 8    624
# 2    621
# 4    581
# 0    548
# 7    522
# 6    501
# 1    495
# 3    492
# 5    483
# Name: count, dtype: int64
# 9    162
# 2    156
# 8    156
# 4    146
# 0    138
# 7    131
# 6    126
# 1    124
# 3    123
# 5    121
# Name: count, dtype: int64
# 9    533
# 8    487
# 2    478
# 4    454
# 7    424
# 0    420
# 6    417
# 3    408
# 1    398
# 5    393
# Name: count, dtype: int64
# 2    143
# 8    137
# 0    128
# 4    127
# 9    115
# 7     98
# 1     97
# 5     90
# 6     84
# 3     84
# Name: count, dtype: int64
# Train Data Shape:  (5515, 512)
# Test Data Shape:  (1383, 512)
# Optimizer Train Data Shape:  (4412, 512)
# Train Accuracy: 0.19383499546690844
# Test Accuracy: 0.1561822125813449
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.6215780998389694
# Prompt 3 Test Accuracy: 0.4935897435897436
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.002070393374741201
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.3605769230769231
# Prompt 9 Test Accuracy: 0.23076923076923078
# Prompt 10 Train Accuracy: 0.7052469135802469
# Prompt 10 Test Accuracy: 0.6358024691358025
# Optimizing Layer 4 at Context Level 275
# (5137, 1, 512)
# (5137, 512)
# 9    508
# 8    504
# 2    500
# 4    452
# 0    408
# 7    376
# 6    347
# 1    344
# 5    336
# 3    328
# Name: count, dtype: int64
# 9    128
# 8    127
# 2    126
# 4    114
# 0    103
# 7     95
# 1     87
# 6     87
# 5     85
# 3     82
# Name: count, dtype: int64
# 9    414
# 8    406
# 2    393
# 4    357
# 0    307
# 7    307
# 1    282
# 5    273
# 6    272
# 3    271
# Name: count, dtype: int64
# 2    107
# 0    101
# 8     98
# 4     95
# 9     94
# 6     75
# 7     69
# 5     63
# 1     62
# 3     57
# Name: count, dtype: int64
# Train Data Shape:  (4103, 512)
# Test Data Shape:  (1034, 512)
# Optimizer Train Data Shape:  (3282, 512)
# Train Accuracy: 0.1888861808432854
# Test Accuracy: 0.16634429400386846
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.568
# Prompt 3 Test Accuracy: 0.5555555555555556
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.4087301587301587
# Prompt 9 Test Accuracy: 0.29133858267716534
# Prompt 10 Train Accuracy: 0.5610236220472441
# Prompt 10 Test Accuracy: 0.5078125
# Optimizing Layer 4 at Context Level 300
# (3342, 1, 512)
# (3342, 512)
# 9    370
# 8    365
# 2    343
# 4    292
# 0    256
# 7    230
# 6    217
# 1    211
# 5    206
# 3    180
# Name: count, dtype: int64
# 9    93
# 8    92
# 2    86
# 4    73
# 0    64
# 7    58
# 6    55
# 1    53
# 5    52
# 3    46
# Name: count, dtype: int64
# 9    300
# 8    288
# 2    276
# 4    228
# 0    204
# 6    183
# 7    178
# 5    172
# 1    165
# 3    142
# Name: count, dtype: int64
# 8    77
# 9    70
# 2    67
# 4    64
# 0    52
# 7    52
# 1    46
# 3    38
# 5    34
# 6    34
# Name: count, dtype: int64
# Train Data Shape:  (2670, 512)
# Test Data Shape:  (672, 512)
# Optimizer Train Data Shape:  (2136, 512)
# Train Accuracy: 0.18726591760299627
# Test Accuracy: 0.15327380952380953
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.22157434402332363
# Prompt 3 Test Accuracy: 0.09302325581395349
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.4767123287671233
# Prompt 9 Test Accuracy: 0.34782608695652173
# Prompt 10 Train Accuracy: 0.6756756756756757
# Prompt 10 Test Accuracy: 0.6774193548387096
# Optimizing Layer 4 at Context Level 325
# (1890, 1, 512)
# (1890, 512)
# 9    234
# 8    224
# 2    202
# 4    175
# 0    144
# 7    114
# 6    111
# 1    109
# 5    100
# 3     95
# Name: count, dtype: int64
# 9    59
# 8    57
# 2    51
# 4    44
# 0    36
# 7    29
# 1    28
# 6    28
# 5    26
# 3    24
# Name: count, dtype: int64
# 9    191
# 8    175
# 2    159
# 4    137
# 0    116
# 6     90
# 1     90
# 7     87
# 5     84
# 3     77
# Name: count, dtype: int64
# 8    49
# 2    43
# 9    43
# 4    38
# 0    28
# 7    27
# 6    21
# 1    19
# 3    18
# 5    16
# Name: count, dtype: int64
# Train Data Shape:  (1508, 512)
# Test Data Shape:  (382, 512)
# Optimizer Train Data Shape:  (1206, 512)
# Train Accuracy: 0.15517241379310345
# Test Accuracy: 0.1544502617801047
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 4 at Context Level 350
# (985, 1, 512)
# (985, 512)
# 9    141
# 8    124
# 2    112
# 4     96
# 0     74
# 7     58
# 1     51
# 6     46
# 3     44
# 5     40
# Name: count, dtype: int64
# 9    36
# 8    31
# 2    28
# 4    24
# 0    19
# 7    15
# 1    13
# 6    12
# 3    11
# 5    10
# Name: count, dtype: int64
# 9    111
# 8     97
# 2     95
# 4     71
# 0     58
# 7     46
# 3     40
# 1     39
# 6     36
# 5     35
# Name: count, dtype: int64
# 9    30
# 8    27
# 4    25
# 2    17
# 0    16
# 7    12
# 1    12
# 6    10
# 5     5
# 3     4
# Name: count, dtype: int64
# Train Data Shape:  (786, 512)
# Test Data Shape:  (199, 512)
# Optimizer Train Data Shape:  (628, 512)
# Train Accuracy: 0.17938931297709923
# Test Accuracy: 0.18090452261306533
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 4 at Context Level 375
# (474, 1, 512)
# (474, 512)
# 9    72
# 8    61
# 2    54
# 0    37
# 4    37
# 7    29
# 1    24
# 3    23
# 5    19
# 6    18
# Name: count, dtype: int64
# 9    19
# 8    16
# 2    14
# 0    10
# 4    10
# 7     8
# 1     7
# 3     6
# 5     5
# 6     5
# Name: count, dtype: int64
# 9    59
# 8    53
# 2    40
# 4    33
# 0    28
# 7    20
# 3    18
# 1    17
# 5    16
# 6    15
# Name: count, dtype: int64
# 2    14
# 9    13
# 0     9
# 7     9
# 8     8
# 1     7
# 3     5
# 4     4
# 5     3
# 6     3
# Name: count, dtype: int64
# Train Data Shape:  (374, 512)
# Test Data Shape:  (100, 512)
# Optimizer Train Data Shape:  (299, 512)
# Train Accuracy: 0.1925133689839572
# Test Accuracy: 0.19
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 4 at Context Level 400
# (192, 1, 512)
# (192, 512)
# 8    33
# 9    31
# 2    20
# 4    16
# 0    11
# 1    11
# 7    10
# 5     7
# 3     6
# 6     5
# Name: count, dtype: int64
# 8    9
# 9    8
# 2    6
# 4    4
# 0    3
# 1    3
# 7    3
# 3    2
# 5    2
# 6    2
# Name: count, dtype: int64
# 8    29
# 9    24
# 2    15
# 4    14
# 0    10
# 1     8
# 7     7
# 3     5
# 5     4
# 6     4
# Name: count, dtype: int64
# 9    7
# 2    5
# 8    4
# 1    3
# 7    3
# 5    3
# 4    2
# 6    1
# 0    1
# 3    1
# Name: count, dtype: int64
# Train Data Shape:  (150, 512)
# Test Data Shape:  (42, 512)
# Optimizer Train Data Shape:  (120, 512)
# Train Accuracy: 0.22
# Test Accuracy: 0.21428571428571427
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 1.0
# Prompt 9 Test Accuracy: 1.0
# Prompt 10 Train Accuracy: 0.0
# Prompt 10 Test Accuracy: 0.0
# Optimizing Layer 4 at Context Level 425
# (73, 1, 512)
# (73, 512)
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.48it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:03<00:00, 15.82it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:07<00:00, 14.85it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:01<00:00, 16.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:08<00:00, 14.56it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:55<00:00, 18.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:00<00:00, 16.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:02<00:00, 15.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:08<00:00, 14.66it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:09<00:00, 14.30it/s]
# Optimizing Layer 5 at Context Level 25
# (10000, 1, 512)
# (10000, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 6    800
# 7    800
# 8    800
# 9    800
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 6    654
# 4    653
# 2    642
# 9    642
# 3    639
# 5    639
# 8    635
# 1    634
# 7    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    166
# 8    165
# 3    161
# 5    161
# 2    158
# 9    158
# 4    147
# 6    146
# Name: count, dtype: int64
# Train Data Shape:  (8000, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6400, 512)
# Train Accuracy: 0.654
# Test Accuracy: 0.481
# Prompt 1 Train Accuracy: 0.6575
# Prompt 1 Test Accuracy: 0.435
# Prompt 2 Train Accuracy: 0.625
# Prompt 2 Test Accuracy: 0.445
# Prompt 3 Train Accuracy: 0.79375
# Prompt 3 Test Accuracy: 0.73
# Prompt 4 Train Accuracy: 0.255
# Prompt 4 Test Accuracy: 0.16
# Prompt 5 Train Accuracy: 0.7775
# Prompt 5 Test Accuracy: 0.555
# Prompt 6 Train Accuracy: 0.64625
# Prompt 6 Test Accuracy: 0.515
# Prompt 7 Train Accuracy: 0.595
# Prompt 7 Test Accuracy: 0.43
# Prompt 8 Train Accuracy: 0.5925
# Prompt 8 Test Accuracy: 0.335
# Prompt 9 Train Accuracy: 0.75375
# ...
# Prompt 5 Train Accuracy: 0.715
# Prompt 5 Test Accuracy: 0.595
# Prompt 6 Train Accuracy: 0.3675
# Prompt 6 Test Accuracy: 0.215
# Prompt 7 Train Accuracy: 0.49937421777221525
# Prompt 7 Test Accuracy: 0.39
# Prompt 8 Train Accuracy: 0.51375
# Prompt 8 Test Accuracy: 0.36
# Prompt 9 Train Accuracy: 0.6575
# Prompt 9 Test Accuracy: 0.54
# Prompt 10 Train Accuracy: 0.58125
# Prompt 10 Test Accuracy: 0.33
# Optimizing Layer 8 at Context Level 150
# (9984, 1, 512)
# (9984, 512)
# 1    800
# 2    800
# 4    800
# 8    800
# 0    799
# 9    799
# 5    798
# 3    797
# 6    796
# 7    796
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 7    200
# 8    200
# 9    200
# 6    199
# Name: count, dtype: int64
# 6    656
# 7    651
# 3    641
# 9    641
# 4    641
# 2    638
# 5    637
# 1    633
# 0    627
# 8    623
# Name: count, dtype: int64
# 8    177
# 0    172
# 1    167
# 2    162
# 5    161
# 4    159
# 9    158
# 3    156
# 7    145
# 6    140
# Name: count, dtype: int64
# Train Data Shape:  (7985, 512)
# Test Data Shape:  (1999, 512)
# Optimizer Train Data Shape:  (6388, 512)
# Train Accuracy: 0.5348778960551033
# Test Accuracy: 0.36368184092046024
# Prompt 1 Train Accuracy: 0.590738423028786
# Prompt 1 Test Accuracy: 0.425
# Prompt 2 Train Accuracy: 0.46875
# Prompt 2 Test Accuracy: 0.285
# Prompt 3 Train Accuracy: 0.67375
# Prompt 3 Test Accuracy: 0.465
# Prompt 4 Train Accuracy: 0.2722710163111669
# Prompt 4 Test Accuracy: 0.2
# Prompt 5 Train Accuracy: 0.7
# Prompt 5 Test Accuracy: 0.515
# Prompt 6 Train Accuracy: 0.36215538847117795
# Prompt 6 Test Accuracy: 0.2
# Prompt 7 Train Accuracy: 0.571608040201005
# Prompt 7 Test Accuracy: 0.38190954773869346
# Prompt 8 Train Accuracy: 0.4849246231155779
# Prompt 8 Test Accuracy: 0.31
# Prompt 9 Train Accuracy: 0.65125
# Prompt 9 Test Accuracy: 0.525
# Prompt 10 Train Accuracy: 0.571964956195244
# Prompt 10 Test Accuracy: 0.33
# Optimizing Layer 8 at Context Level 175
# (9835, 1, 512)
# (9835, 512)
# 9    796
# 2    794
# 8    794
# 4    792
# 0    790
# 6    782
# 5    780
# 1    779
# 7    779
# 3    777
# Name: count, dtype: int64
# 9    200
# 2    199
# 4    199
# 8    199
# 0    198
# 5    196
# 6    196
# 1    195
# 3    195
# 7    195
# Name: count, dtype: int64
# 9    645
# 6    641
# 4    637
# 8    635
# 2    635
# 7    625
# 3    622
# 5    622
# 0    617
# 1    611
# Name: count, dtype: int64
# 0    173
# 1    168
# 8    159
# 2    159
# 5    158
# 3    155
# 4    155
# 7    154
# 9    151
# 6    141
# Name: count, dtype: int64
# Train Data Shape:  (7863, 512)
# Test Data Shape:  (1972, 512)
# Optimizer Train Data Shape:  (6290, 512)
# Train Accuracy: 0.5430497265674679
# Test Accuracy: 0.39046653144016225
# Prompt 1 Train Accuracy: 0.5569620253164557
# Prompt 1 Test Accuracy: 0.398989898989899
# Prompt 2 Train Accuracy: 0.4749679075738126
# Prompt 2 Test Accuracy: 0.3384615384615385
# Prompt 3 Train Accuracy: 0.7204030226700252
# Prompt 3 Test Accuracy: 0.6130653266331658
# Prompt 4 Train Accuracy: 0.2471042471042471
# Prompt 4 Test Accuracy: 0.14358974358974358
# Prompt 5 Train Accuracy: 0.7083333333333334
# Prompt 5 Test Accuracy: 0.6080402010050251
# Prompt 6 Train Accuracy: 0.4371794871794872
# Prompt 6 Test Accuracy: 0.28061224489795916
# Prompt 7 Train Accuracy: 0.5166240409207161
# Prompt 7 Test Accuracy: 0.32142857142857145
# Prompt 8 Train Accuracy: 0.5083440308087291
# Prompt 8 Test Accuracy: 0.358974358974359
# Prompt 9 Train Accuracy: 0.6624685138539043
# Prompt 9 Test Accuracy: 0.457286432160804
# Prompt 10 Train Accuracy: 0.5879396984924623
# Prompt 10 Test Accuracy: 0.375
# Optimizing Layer 8 at Context Level 200
# (9361, 1, 512)
# (9361, 512)
# 8    779
# 2    777
# 9    776
# 4    764
# 0    755
# 6    732
# 7    732
# 5    728
# 1    724
# 3    718
# Name: count, dtype: int64
# 2    195
# 8    195
# 9    195
# 4    192
# 0    189
# 7    184
# 6    183
# 5    182
# 1    181
# 3    180
# Name: count, dtype: int64
# 9    632
# 8    628
# 4    620
# 2    605
# 0    591
# 6    588
# 7    584
# 3    584
# 1    581
# 5    575
# Name: count, dtype: int64
# 2    172
# 0    164
# 5    153
# 8    151
# 7    148
# 9    144
# 4    144
# 6    144
# 1    143
# 3    134
# Name: count, dtype: int64
# Train Data Shape:  (7485, 512)
# Test Data Shape:  (1876, 512)
# Optimizer Train Data Shape:  (5988, 512)
# Train Accuracy: 0.5352037408149632
# Test Accuracy: 0.3773987206823028
# Prompt 1 Train Accuracy: 0.5708609271523178
# Prompt 1 Test Accuracy: 0.30687830687830686
# Prompt 2 Train Accuracy: 0.4488950276243094
# Prompt 2 Test Accuracy: 0.30939226519337015
# Prompt 3 Train Accuracy: 0.7541827541827542
# Prompt 3 Test Accuracy: 0.6205128205128205
# Prompt 4 Train Accuracy: 0.28969359331476324
# Prompt 4 Test Accuracy: 0.20555555555555555
# Prompt 5 Train Accuracy: 0.6819371727748691
# Prompt 5 Test Accuracy: 0.5364583333333334
# Prompt 6 Train Accuracy: 0.3942307692307692
# Prompt 6 Test Accuracy: 0.24725274725274726
# Prompt 7 Train Accuracy: 0.4890710382513661
# Prompt 7 Test Accuracy: 0.31693989071038253
# Prompt 8 Train Accuracy: 0.4494535519125683
# Prompt 8 Test Accuracy: 0.30978260869565216
# Prompt 9 Train Accuracy: 0.6405648267008985
# Prompt 9 Test Accuracy: 0.5076923076923077
# Prompt 10 Train Accuracy: 0.595360824742268
# Prompt 10 Test Accuracy: 0.37948717948717947
# Optimizing Layer 8 at Context Level 225
# (8394, 1, 512)
# (8394, 512)
# 9    738
# 2    720
# 8    709
# 4    692
# 0    675
# 7    652
# 1    636
# 6    635
# 5    630
# 3    624
# Name: count, dtype: int64
# 9    185
# 2    180
# 8    178
# 4    174
# 0    169
# 7    164
# 1    160
# 6    159
# 5    158
# 3    156
# Name: count, dtype: int64
# 9    604
# 8    563
# 2    562
# 4    548
# 7    524
# 0    522
# 1    520
# 3    515
# 6    509
# 5    501
# Name: count, dtype: int64
# 2    158
# 0    153
# 8    146
# 4    144
# 9    134
# 5    129
# 7    128
# 6    126
# 1    116
# 3    109
# Name: count, dtype: int64
# Train Data Shape:  (6711, 512)
# Test Data Shape:  (1683, 512)
# Optimizer Train Data Shape:  (5368, 512)
# Train Accuracy: 0.5347936224109671
# Test Accuracy: 0.3600713012477718
# Prompt 1 Train Accuracy: 0.5555555555555556
# Prompt 1 Test Accuracy: 0.3431952662721893
# Prompt 2 Train Accuracy: 0.4638364779874214
# Prompt 2 Test Accuracy: 0.25625
# Prompt 3 Train Accuracy: 0.775
# Prompt 3 Test Accuracy: 0.5388888888888889
# Prompt 4 Train Accuracy: 0.14262820512820512
# Prompt 4 Test Accuracy: 0.07051282051282051
# Prompt 5 Train Accuracy: 0.6950867052023122
# Prompt 5 Test Accuracy: 0.5862068965517241
# Prompt 6 Train Accuracy: 0.3142857142857143
# Prompt 6 Test Accuracy: 0.17721518987341772
# Prompt 7 Train Accuracy: 0.5433070866141733
# Prompt 7 Test Accuracy: 0.389937106918239
# Prompt 8 Train Accuracy: 0.4723926380368098
# Prompt 8 Test Accuracy: 0.21951219512195122
# Prompt 9 Train Accuracy: 0.6248236953455572
# Prompt 9 Test Accuracy: 0.4550561797752809
# Prompt 10 Train Accuracy: 0.6734417344173442
# Prompt 10 Test Accuracy: 0.4864864864864865
# Optimizing Layer 8 at Context Level 250
# (6898, 1, 512)
# (6898, 512)
# 9    648
# 8    624
# 2    621
# 4    581
# 0    548
# 7    522
# 6    501
# 1    495
# 3    492
# 5    483
# Name: count, dtype: int64
# 9    162
# 2    156
# 8    156
# 4    146
# 0    138
# 7    131
# 6    126
# 1    124
# 3    123
# 5    121
# Name: count, dtype: int64
# 9    533
# 8    487
# 2    478
# 4    454
# 7    424
# 0    420
# 6    417
# 3    408
# 1    398
# 5    393
# Name: count, dtype: int64
# 2    143
# 8    137
# 0    128
# 4    127
# 9    115
# 7     98
# 1     97
# 5     90
# 6     84
# 3     84
# Name: count, dtype: int64
# Train Data Shape:  (5515, 512)
# Test Data Shape:  (1383, 512)
# Optimizer Train Data Shape:  (4412, 512)
# Train Accuracy: 0.4786944696282865
# Test Accuracy: 0.34345625451916123
# Prompt 1 Train Accuracy: 0.4981751824817518
# Prompt 1 Test Accuracy: 0.21739130434782608
# Prompt 2 Train Accuracy: 0.3797979797979798
# Prompt 2 Test Accuracy: 0.2903225806451613
# Prompt 3 Train Accuracy: 0.7809983896940419
# Prompt 3 Test Accuracy: 0.6666666666666666
# Prompt 4 Train Accuracy: 0.03048780487804878
# Prompt 4 Test Accuracy: 0.032520325203252036
# Prompt 5 Train Accuracy: 0.6540447504302926
# Prompt 5 Test Accuracy: 0.5136986301369864
# Prompt 6 Train Accuracy: 0.19668737060041408
# Prompt 6 Test Accuracy: 0.0743801652892562
# Prompt 7 Train Accuracy: 0.4231536926147705
# Prompt 7 Test Accuracy: 0.2777777777777778
# Prompt 8 Train Accuracy: 0.21264367816091953
# Prompt 8 Test Accuracy: 0.09923664122137404
# Prompt 9 Train Accuracy: 0.6923076923076923
# Prompt 9 Test Accuracy: 0.532051282051282
# Prompt 10 Train Accuracy: 0.6929012345679012
# Prompt 10 Test Accuracy: 0.5308641975308642
# Optimizing Layer 8 at Context Level 275
# (5137, 1, 512)
# (5137, 512)
# 9    508
# 8    504
# 2    500
# 4    452
# 0    408
# 7    376
# 6    347
# 1    344
# 5    336
# 3    328
# Name: count, dtype: int64
# 9    128
# 8    127
# 2    126
# 4    114
# 0    103
# 7     95
# 1     87
# 6     87
# 5     85
# 3     82
# Name: count, dtype: int64
# 9    414
# 8    406
# 2    393
# 4    357
# 0    307
# 7    307
# 1    282
# 5    273
# 6    272
# 3    271
# Name: count, dtype: int64
# 2    107
# 0    101
# 8     98
# 4     95
# 9     94
# 6     75
# 7     69
# 5     63
# 1     62
# 3     57
# Name: count, dtype: int64
# Train Data Shape:  (4103, 512)
# Test Data Shape:  (1034, 512)
# Optimizer Train Data Shape:  (3282, 512)
# Train Accuracy: 0.3767974652693151
# Test Accuracy: 0.3114119922630561
# Prompt 1 Train Accuracy: 0.14215686274509803
# Prompt 1 Test Accuracy: 0.20388349514563106
# Prompt 2 Train Accuracy: 0.020348837209302327
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.846
# Prompt 3 Test Accuracy: 0.746031746031746
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.6792035398230089
# Prompt 5 Test Accuracy: 0.5526315789473685
# Prompt 6 Train Accuracy: 0.03273809523809524
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.11527377521613832
# Prompt 7 Test Accuracy: 0.04597701149425287
# Prompt 8 Train Accuracy: 0.007978723404255319
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.6884920634920635
# Prompt 9 Test Accuracy: 0.6062992125984252
# Prompt 10 Train Accuracy: 0.6889763779527559
# Prompt 10 Test Accuracy: 0.4921875
# Optimizing Layer 8 at Context Level 300
# (3342, 1, 512)
# (3342, 512)
# 9    370
# 8    365
# 2    343
# 4    292
# 0    256
# 7    230
# 6    217
# 1    211
# 5    206
# 3    180
# Name: count, dtype: int64
# 9    93
# 8    92
# 2    86
# 4    73
# 0    64
# 7    58
# 6    55
# 1    53
# 5    52
# 3    46
# Name: count, dtype: int64
# 9    300
# 8    288
# 2    276
# 4    228
# 0    204
# 6    183
# 7    178
# 5    172
# 1    165
# 3    142
# Name: count, dtype: int64
# 8    77
# 9    70
# 2    67
# 4    64
# 0    52
# 7    52
# 1    46
# 3    38
# 5    34
# 6    34
# Name: count, dtype: int64
# Train Data Shape:  (2670, 512)
# Test Data Shape:  (672, 512)
# Optimizer Train Data Shape:  (2136, 512)
# Train Accuracy: 0.3415730337078652
# Test Accuracy: 0.26339285714285715
# Prompt 1 Train Accuracy: 0.015625
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.7259475218658892
# Prompt 3 Test Accuracy: 0.5697674418604651
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.4349315068493151
# Prompt 5 Test Accuracy: 0.273972602739726
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.7424657534246575
# Prompt 9 Test Accuracy: 0.6413043478260869
# Prompt 10 Train Accuracy: 0.7054054054054054
# Prompt 10 Test Accuracy: 0.5268817204301075
# Optimizing Layer 8 at Context Level 325
# (1890, 1, 512)
# (1890, 512)
# 9    234
# 8    224
# 2    202
# 4    175
# 0    144
# 7    114
# 6    111
# 1    109
# 5    100
# 3     95
# Name: count, dtype: int64
# 9    59
# 8    57
# 2    51
# 4    44
# 0    36
# 7    29
# 1    28
# 6    28
# 5    26
# 3    24
# Name: count, dtype: int64
# 9    191
# 8    175
# 2    159
# 4    137
# 0    116
# 6     90
# 1     90
# 7     87
# 5     84
# 3     77
# Name: count, dtype: int64
# 8    49
# 2    43
# 9    43
# 4    38
# 0    28
# 7    27
# 6    21
# 1    19
# 3    18
# 5    16
# Name: count, dtype: int64
# Train Data Shape:  (1508, 512)
# Test Data Shape:  (382, 512)
# Optimizer Train Data Shape:  (1206, 512)
# Train Accuracy: 0.2612732095490716
# Test Accuracy: 0.2356020942408377
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.23267326732673269
# Prompt 3 Test Accuracy: 0.23529411764705882
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.6607142857142857
# Prompt 9 Test Accuracy: 0.6491228070175439
# Prompt 10 Train Accuracy: 0.8504273504273504
# Prompt 10 Test Accuracy: 0.6949152542372882
# Optimizing Layer 8 at Context Level 350
# (985, 1, 512)
# (985, 512)
# 9    141
# 8    124
# 2    112
# 4     96
# 0     74
# 7     58
# 1     51
# 6     46
# 3     44
# 5     40
# Name: count, dtype: int64
# 9    36
# 8    31
# 2    28
# 4    24
# 0    19
# 7    15
# 1    13
# 6    12
# 3    11
# 5    10
# Name: count, dtype: int64
# 9    111
# 8     97
# 2     95
# 4     71
# 0     58
# 7     46
# 3     40
# 1     39
# 6     36
# 5     35
# Name: count, dtype: int64
# 9    30
# 8    27
# 4    25
# 2    17
# 0    16
# 7    12
# 1    12
# 6    10
# 5     5
# 3     4
# Name: count, dtype: int64
# Train Data Shape:  (786, 512)
# Test Data Shape:  (199, 512)
# Optimizer Train Data Shape:  (628, 512)
# Train Accuracy: 0.17938931297709923
# Test Accuracy: 0.18090452261306533
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 8 at Context Level 375
# (474, 1, 512)
# (474, 512)
# 9    72
# 8    61
# 2    54
# 0    37
# 4    37
# 7    29
# 1    24
# 3    23
# 5    19
# 6    18
# Name: count, dtype: int64
# 9    19
# 8    16
# 2    14
# 0    10
# 4    10
# 7     8
# 1     7
# 3     6
# 5     5
# 6     5
# Name: count, dtype: int64
# 9    59
# 8    53
# 2    40
# 4    33
# 0    28
# 7    20
# 3    18
# 1    17
# 5    16
# 6    15
# Name: count, dtype: int64
# 2    14
# 9    13
# 0     9
# 7     9
# 8     8
# 1     7
# 3     5
# 4     4
# 5     3
# 6     3
# Name: count, dtype: int64
# Train Data Shape:  (374, 512)
# Test Data Shape:  (100, 512)
# Optimizer Train Data Shape:  (299, 512)
# Train Accuracy: 0.1925133689839572
# Test Accuracy: 0.19
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 8 at Context Level 400
# (192, 1, 512)
# (192, 512)
# 8    33
# 9    31
# 2    20
# 4    16
# 0    11
# 1    11
# 7    10
# 5     7
# 3     6
# 6     5
# Name: count, dtype: int64
# 8    9
# 9    8
# 2    6
# 4    4
# 0    3
# 1    3
# 7    3
# 3    2
# 5    2
# 6    2
# Name: count, dtype: int64
# 8    29
# 9    24
# 2    15
# 4    14
# 0    10
# 1     8
# 7     7
# 3     5
# 5     4
# 6     4
# Name: count, dtype: int64
# 9    7
# 2    5
# 8    4
# 1    3
# 7    3
# 5    3
# 4    2
# 6    1
# 0    1
# 3    1
# Name: count, dtype: int64
# Train Data Shape:  (150, 512)
# Test Data Shape:  (42, 512)
# Optimizer Train Data Shape:  (120, 512)
# Train Accuracy: 0.22
# Test Accuracy: 0.21428571428571427
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 1.0
# Prompt 9 Test Accuracy: 1.0
# Prompt 10 Train Accuracy: 0.0
# Prompt 10 Test Accuracy: 0.0
# Optimizing Layer 8 at Context Level 425
# (73, 1, 512)
# (73, 512)
