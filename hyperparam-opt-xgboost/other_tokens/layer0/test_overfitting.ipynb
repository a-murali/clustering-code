# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

import xgboost as xgb
from xgboost import XGBClassifier
from xgboost.core import XGBoostError
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


import csv

import cupy as cp

import gc

# %%
df = pd.read_csv("../../story_dataset.csv")
df
# Out:
#       prompt_id                                 prompt  \
# 0             1    Once upon a time there was a dragon
# 1             1    Once upon a time there was a dragon
# 2             1    Once upon a time there was a dragon
# 3             1    Once upon a time there was a dragon
# 4             1    Once upon a time there was a dragon
# ...         ...                                    ...
# 9995         10  Once upon a time there was a poor boy
# 9996         10  Once upon a time there was a poor boy
# 9997         10  Once upon a time there was a poor boy
# 9998         10  Once upon a time there was a poor boy
# 9999         10  Once upon a time there was a poor boy
#
#                                                   story  \
# 0     Once upon a time there was a dragon. It was bi...
# 1     Once upon a time there was a dragon. He loved ...
# 2     Once upon a time there was a dragon named Sam....
# 3     Once upon a time there was a dragon. He was a ...
# 4     Once upon a time there was a dragon. The drago...
# ...                                                 ...
# 9995  Once upon a time there was a poor boy named Ti...
# 9996  Once upon a time there was a poor boy named Ti...
# 9997  Once upon a time there was a poor boy named Ti...
# 9998  Once upon a time there was a poor boy named Ti...
# 9999  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story
# 0      ./hidden_states/prompt_1.npz                  273
# 1      ./hidden_states/prompt_1.npz                  246
# 2      ./hidden_states/prompt_1.npz                  397
# 3      ./hidden_states/prompt_1.npz                  294
# 4      ./hidden_states/prompt_1.npz                  296
# ...                             ...                  ...
# 9995  ./hidden_states/prompt_10.npz                  315
# 9996  ./hidden_states/prompt_10.npz                  270
# 9997  ./hidden_states/prompt_10.npz                  206
# 9998  ./hidden_states/prompt_10.npz                  375
# 9999  ./hidden_states/prompt_10.npz                  341
#
# [10000 rows x 5 columns]

# %%
hidden_states_by_cl = {}
curr_labels = {}
NUM_PROMPTS = 10
layer = 8

# %%
max_story_len = max(df[:NUM_PROMPTS*1000]["len_generated_story"])
max_story_len
# Out:
# 522

# %%
df[df["len_generated_story"] >= max_story_len]
# Out:
#       prompt_id                                 prompt  \
# 9851         10  Once upon a time there was a poor boy
#
#                                                   story  \
# 9851  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story
# 9851  ./hidden_states/prompt_10.npz                  522

# %%
min_story_len = min(df["len_generated_story"])
min_story_len
# Out:
# 37

# %%
context_levels = [0] #get hs used to generate second token
context_levels.extend([i for i in range(23, max_story_len, 25)]) #actual context level is context_level + 2 (gather hs to generate the context_level + 2 token)

# %%
hidden_states_by_cl = {f"cl_{cl+2}": [] for cl in context_levels}
curr_labels = {f"cl_{cl+2}": [] for cl in context_levels}

for prompt_id in range(1, NUM_PROMPTS + 1):
    with np.load(f'../../../llamatales-xgboost-ii/hidden_states/prompt_{prompt_id}.npz') as loaded_data:

        for i in tqdm(range(1000)):
            hs = loaded_data[f"arr_{i}"]  # load once

            for context_level in context_levels:
                if context_level >= hs.shape[0]:
                    continue

                key = f"cl_{context_level + 2}"

                hidden_states_by_cl[key].append(
                    hs[context_level][layer][0].astype("float32")
                )
                curr_labels[key].append(prompt_id - 1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:28<00:00, 34.65it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:27<00:00, 35.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:30<00:00, 32.99it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:27<00:00, 36.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:29<00:00, 33.98it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:27<00:00, 36.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:27<00:00, 35.95it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:28<00:00, 35.49it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:30<00:00, 32.78it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:30<00:00, 32.46it/s]

# %%
def safe_split(total, train_ratio=0.8):
    train = int(train_ratio * total)   # floor
    test  = total - train              # leftover
    return train, test

def build_dataset(curr_context_level_hs, curr_labels, train_ratio=0.8):
    """
    Groups samples by prompt_id, splits safely into train/test,
    and returns X_train, y_train, X_test, y_test.
    """

    unique_ids = sorted(set(curr_labels))

    X_train_list = []
    X_test_list = []
    y_train_list = []
    y_test_list = []

    for pid in unique_ids:

        # get samples for this prompt id
        mask = (curr_labels == pid)
        X_pid = curr_context_level_hs[mask]
        y_pid = curr_labels[mask]

        total = len(X_pid)
        train_n, test_n = safe_split(total, train_ratio)

        # split
        X_train_list.append(X_pid[:train_n])
        y_train_list.append(y_pid[:train_n])

        X_test_list.append(X_pid[train_n:])
        y_test_list.append(y_pid[train_n:])

    # concatenate all prompt-id blocks
    X_train = np.concatenate(X_train_list, axis=0)
    y_train = np.concatenate(y_train_list, axis=0)
    X_test  = np.concatenate(X_test_list, axis=0)
    y_test  = np.concatenate(y_test_list, axis=0)

    # return cp.array(X_train), cp.array(y_train), cp.array(X_test), cp.array(y_test)
    return X_train, y_train, X_test, y_test

# %%
np.array(hidden_states_by_cl[f"cl_2"]).shape
# Out:
# (10000, 1, 512)

# %%
print(np.array(curr_labels[f"cl_2"]).shape)
# Out:
# (10000,)

# %%
# with open("results-test.csv", "w+", newline='') as csvfile:
#     csv_writer = csv.writer(csvfile, delimiter=',')
#     header = ['Layer', 'Context_Level', 'Train_Accuracy', 'Test_Accuracy']
#     prompt_headers = []
#     for i in range(1, 11):
#         prompt_headers.extend([f"Prompt_{i}_Train_Accuracy", f"Prompt_{i}_Test_Accuracy"])

#     header.extend(prompt_headers)
#     csv_writer.writerow(header)

for context_level in context_levels[1:]:
    print(f"Optimizing Layer {layer} at Context Level {context_level + 2}")
    cl_hs_array = hidden_states_by_cl[f"cl_{context_level + 2}"]
    curr_label_set = curr_labels[f"cl_{context_level + 2}"]
    # print(cl_hs_array[0].shape)
    # print(cl_hs_array[-1].shape)
    #1x512

    print(np.array(cl_hs_array).shape)
    for hs in range(len(cl_hs_array)):
        cl_hs_array[hs] = cl_hs_array[hs].flatten()

    curr_context_level_hs = np.array(cl_hs_array)
    print(curr_context_level_hs.shape)

    curr_label_set = np.array(curr_label_set)

    unique_ids = sorted(set(curr_label_set))

    if(len(unique_ids) < 10): break
    
    X_train, y_train, X_test, y_test = build_dataset(curr_context_level_hs, curr_label_set)

    X_train_opt, X_valid, y_train_opt, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state=42)

    #split into train and test and see how many samples of each class are in the test set (might explain 0.0 acc performance in test set).
    print(pd.Series(y_train).value_counts())
    print(pd.Series(y_test).value_counts())
    print(pd.Series(y_train_opt).value_counts())
    print(pd.Series(y_valid).value_counts())

    print("Train Data Shape: ", X_train.shape)
    print("Test Data Shape: ", X_test.shape)
    print("Optimizer Train Data Shape: ", X_train_opt.shape)

    X_train = cp.array(X_train)
    y_train = cp.array(y_train)
    X_test = cp.array(X_test)
    y_test = cp.array(y_test)

    X_train_opt = cp.array(X_train_opt)
    y_train_opt = cp.array(y_train_opt)
    X_valid = cp.array(X_valid)
    y_valid = cp.array(y_valid)

    classifier = XGBClassifier(max_depth = 3, 
                               reg_alpha = 10, 
                               reg_lambda = 10, 
                               gamma = 10, 
                               subsample = 0.75,
                               colsample_bytree = 0.75,
                               eta = 0.01,
                               n_estimators = 500,
                               # min_child_weight = 20,
                               seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids), tree_method='hist', device='cuda')
    classifier.fit(X_train, y_train)
    preds_train = classifier.predict(X_train)
    preds = classifier.predict(X_test)

    train_accuracy = np.mean(cp.array(preds_train) == y_train)
    accuracy = np.mean(cp.array(preds) == y_test)

    print(f"Train Accuracy: {train_accuracy}")
    print(f"Test Accuracy: {accuracy}")

    prompt_accs = []

    for i in range(10):
        mask = y_test == i
        prompt_test = y_test[mask]
        prompt_preds = cp.array(preds)[mask]
        prompt_test_acc = np.mean(prompt_preds == prompt_test)

        mask_train = y_train == i
        prompt_train = y_train[mask_train]
        prompt_preds_train = cp.array(preds_train)[mask_train]
        prompt_train_acc = np.mean(prompt_preds_train == prompt_train)

        print(f"Prompt {i + 1} Train Accuracy: {prompt_train_acc}")
        print(f"Prompt {i + 1} Test Accuracy: {prompt_test_acc}")

        prompt_accs.append(prompt_train_acc)
        prompt_accs.append(prompt_test_acc)

    
    with open("results-test.csv", "a+", newline='') as csvfile:
        csv_writer = csv.writer(csvfile, delimiter=',')
        values = [layer, context_level + 2, train_accuracy, accuracy]
        values.extend(prompt_accs)
        csv_writer.writerow(values)
            


    del classifier, X_train, y_train, X_test, y_test, preds

    # XGBoost cleanup
    try:
        booster = classifier.get_booster()
        del booster
    except:
        pass
    
    # CuPy cleanup
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    
    gc.collect()
# Out:
# Optimizing Layer 8 at Context Level 25
# (10000, 1, 512)
# (10000, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 6    800
# 7    800
# 8    800
# 9    800
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 6    654
# 4    653
# 2    642
# 9    642
# 3    639
# 5    639
# 8    635
# 1    634
# 7    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    166
# 8    165
# 3    161
# 5    161
# 2    158
# 9    158
# 4    147
# 6    146
# Name: count, dtype: int64
# Train Data Shape:  (8000, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6400, 512)
# Train Accuracy: 0.73425
# Test Accuracy: 0.6405
# Prompt 1 Train Accuracy: 0.79625
# Prompt 1 Test Accuracy: 0.715
# Prompt 2 Train Accuracy: 0.65375
# Prompt 2 Test Accuracy: 0.515
# Prompt 3 Train Accuracy: 0.8375
# Prompt 3 Test Accuracy: 0.77
# Prompt 4 Train Accuracy: 0.46125
# Prompt 4 Test Accuracy: 0.325
# Prompt 5 Train Accuracy: 0.85875
# Prompt 5 Test Accuracy: 0.76
# Prompt 6 Train Accuracy: 0.68875
# Prompt 6 Test Accuracy: 0.565
# Prompt 7 Train Accuracy: 0.63375
# Prompt 7 Test Accuracy: 0.515
# Prompt 8 Train Accuracy: 0.75875
# Prompt 8 Test Accuracy: 0.665
# Prompt 9 Train Accuracy: 0.81
# Prompt 9 Test Accuracy: 0.8
# Prompt 10 Train Accuracy: 0.84375
# Prompt 10 Test Accuracy: 0.775
# Optimizing Layer 8 at Context Level 50
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.5985748218527316
# Test Accuracy: 0.4645
# Prompt 1 Train Accuracy: 0.56125
# Prompt 1 Test Accuracy: 0.46
# Prompt 2 Train Accuracy: 0.53125
# Prompt 2 Test Accuracy: 0.375
# Prompt 3 Train Accuracy: 0.70625
# Prompt 3 Test Accuracy: 0.585
# Prompt 4 Train Accuracy: 0.3125
# Prompt 4 Test Accuracy: 0.225
# Prompt 5 Train Accuracy: 0.785
# Prompt 5 Test Accuracy: 0.66
# Prompt 6 Train Accuracy: 0.52
# Prompt 6 Test Accuracy: 0.37
# Prompt 7 Train Accuracy: 0.5556946182728411
# Prompt 7 Test Accuracy: 0.34
# Prompt 8 Train Accuracy: 0.58375
# Prompt 8 Test Accuracy: 0.42
# Prompt 9 Train Accuracy: 0.76625
# Prompt 9 Test Accuracy: 0.69
# Prompt 10 Train Accuracy: 0.66375
# Prompt 10 Test Accuracy: 0.52
# Optimizing Layer 8 at Context Level 75
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.5478184773096637
# Test Accuracy: 0.419
# Prompt 1 Train Accuracy: 0.565
# Prompt 1 Test Accuracy: 0.465
# Prompt 2 Train Accuracy: 0.5225
# Prompt 2 Test Accuracy: 0.365
# Prompt 3 Train Accuracy: 0.69125
# Prompt 3 Test Accuracy: 0.575
# Prompt 4 Train Accuracy: 0.29375
# Prompt 4 Test Accuracy: 0.195
# Prompt 5 Train Accuracy: 0.68875
# Prompt 5 Test Accuracy: 0.535
# Prompt 6 Train Accuracy: 0.4325
# Prompt 6 Test Accuracy: 0.3
# Prompt 7 Train Accuracy: 0.4806007509386733
# Prompt 7 Test Accuracy: 0.37
# Prompt 8 Train Accuracy: 0.505
# Prompt 8 Test Accuracy: 0.38
# Prompt 9 Train Accuracy: 0.7175
# Prompt 9 Test Accuracy: 0.58
# Prompt 10 Train Accuracy: 0.58125
# Prompt 10 Test Accuracy: 0.425
# Optimizing Layer 8 at Context Level 100
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.5158144768096012
# Test Accuracy: 0.3775
# Prompt 1 Train Accuracy: 0.54
# Prompt 1 Test Accuracy: 0.375
# Prompt 2 Train Accuracy: 0.515
# Prompt 2 Test Accuracy: 0.34
# Prompt 3 Train Accuracy: 0.6625
# Prompt 3 Test Accuracy: 0.51
# Prompt 4 Train Accuracy: 0.2875
# Prompt 4 Test Accuracy: 0.185
# Prompt 5 Train Accuracy: 0.62875
# Prompt 5 Test Accuracy: 0.585
# Prompt 6 Train Accuracy: 0.38125
# Prompt 6 Test Accuracy: 0.255
# Prompt 7 Train Accuracy: 0.4618272841051314
# Prompt 7 Test Accuracy: 0.27
# Prompt 8 Train Accuracy: 0.48
# Prompt 8 Test Accuracy: 0.385
# Prompt 9 Train Accuracy: 0.67625
# Prompt 9 Test Accuracy: 0.53
# Prompt 10 Train Accuracy: 0.525
# Prompt 10 Test Accuracy: 0.34
# Optimizing Layer 8 at Context Level 125
# (9999, 1, 512)
# (9999, 512)
# 0    800
# 1    800
# 2    800
# 3    800
# 4    800
# 5    800
# 7    800
# 8    800
# 9    800
# 6    799
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 6    200
# 7    200
# 8    200
# 9    200
# Name: count, dtype: int64
# 9    654
# 5    646
# 4    645
# 2    642
# 8    640
# 3    638
# 6    636
# 7    636
# 1    634
# 0    628
# Name: count, dtype: int64
# 0    172
# 1    166
# 7    164
# 6    163
# 3    162
# 8    160
# 2    158
# 4    155
# 5    154
# 9    146
# Name: count, dtype: int64
# Train Data Shape:  (7999, 512)
# Test Data Shape:  (2000, 512)
# Optimizer Train Data Shape:  (6399, 512)
# Train Accuracy: 0.506938367295912
# Test Accuracy: 0.3665
# Prompt 1 Train Accuracy: 0.5025
# Prompt 1 Test Accuracy: 0.35
# Prompt 2 Train Accuracy: 0.49
# Prompt 2 Test Accuracy: 0.285
# Prompt 3 Train Accuracy: 0.67875
# Prompt 3 Test Accuracy: 0.48
# Prompt 4 Train Accuracy: 0.2875
# Prompt 4 Test Accuracy: 0.165
# Prompt 5 Train Accuracy: 0.68375
# Prompt 5 Test Accuracy: 0.61
# Prompt 6 Train Accuracy: 0.3325
# Prompt 6 Test Accuracy: 0.22
# Prompt 7 Train Accuracy: 0.45056320400500627
# Prompt 7 Test Accuracy: 0.33
# Prompt 8 Train Accuracy: 0.47
# Prompt 8 Test Accuracy: 0.345
# Prompt 9 Train Accuracy: 0.6225
# Prompt 9 Test Accuracy: 0.54
# Prompt 10 Train Accuracy: 0.55125
# Prompt 10 Test Accuracy: 0.34
# Optimizing Layer 8 at Context Level 150
# (9984, 1, 512)
# (9984, 512)
# 1    800
# 2    800
# 4    800
# 8    800
# 0    799
# 9    799
# 5    798
# 3    797
# 6    796
# 7    796
# Name: count, dtype: int64
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# 5    200
# 7    200
# 8    200
# 9    200
# 6    199
# Name: count, dtype: int64
# 6    656
# 7    651
# 3    641
# 9    641
# 4    641
# 2    638
# 5    637
# 1    633
# 0    627
# 8    623
# Name: count, dtype: int64
# 8    177
# 0    172
# 1    167
# 2    162
# 5    161
# 4    159
# 9    158
# 3    156
# 7    145
# 6    140
# Name: count, dtype: int64
# Train Data Shape:  (7985, 512)
# Test Data Shape:  (1999, 512)
# Optimizer Train Data Shape:  (6388, 512)
# Train Accuracy: 0.5018159048215404
# Test Accuracy: 0.35767883941970985
# Prompt 1 Train Accuracy: 0.5707133917396746
# Prompt 1 Test Accuracy: 0.42
# Prompt 2 Train Accuracy: 0.435
# Prompt 2 Test Accuracy: 0.28
# Prompt 3 Train Accuracy: 0.6275
# Prompt 3 Test Accuracy: 0.46
# Prompt 4 Train Accuracy: 0.2572145545796738
# Prompt 4 Test Accuracy: 0.18
# Prompt 5 Train Accuracy: 0.67875
# Prompt 5 Test Accuracy: 0.53
# Prompt 6 Train Accuracy: 0.3383458646616541
# Prompt 6 Test Accuracy: 0.19
# Prompt 7 Train Accuracy: 0.5276381909547738
# Prompt 7 Test Accuracy: 0.3768844221105528
# Prompt 8 Train Accuracy: 0.45226130653266333
# Prompt 8 Test Accuracy: 0.315
# Prompt 9 Train Accuracy: 0.60625
# Prompt 9 Test Accuracy: 0.505
# Prompt 10 Train Accuracy: 0.523153942428035
# Prompt 10 Test Accuracy: 0.32
# Optimizing Layer 8 at Context Level 175
# (9835, 1, 512)
# (9835, 512)
# 9    796
# 2    794
# 8    794
# 4    792
# 0    790
# 6    782
# 5    780
# 1    779
# 7    779
# 3    777
# Name: count, dtype: int64
# 9    200
# 2    199
# 4    199
# 8    199
# 0    198
# 5    196
# 6    196
# 1    195
# 3    195
# 7    195
# Name: count, dtype: int64
# 9    645
# 6    641
# 4    637
# 8    635
# 2    635
# 7    625
# 3    622
# 5    622
# 0    617
# 1    611
# Name: count, dtype: int64
# 0    173
# 1    168
# 8    159
# 2    159
# 5    158
# 3    155
# 4    155
# 7    154
# 9    151
# 6    141
# Name: count, dtype: int64
# Train Data Shape:  (7863, 512)
# Test Data Shape:  (1972, 512)
# Optimizer Train Data Shape:  (6290, 512)
# Train Accuracy: 0.5010810123362585
# Test Accuracy: 0.385395537525355
# Prompt 1 Train Accuracy: 0.49493670886075947
# Prompt 1 Test Accuracy: 0.3888888888888889
# Prompt 2 Train Accuracy: 0.44030808729139925
# Prompt 2 Test Accuracy: 0.3384615384615385
# Prompt 3 Train Accuracy: 0.6763224181360201
# Prompt 3 Test Accuracy: 0.5879396984924623
# Prompt 4 Train Accuracy: 0.2277992277992278
# Prompt 4 Test Accuracy: 0.14358974358974358
# Prompt 5 Train Accuracy: 0.6616161616161617
# Prompt 5 Test Accuracy: 0.6231155778894473
# Prompt 6 Train Accuracy: 0.4
# Prompt 6 Test Accuracy: 0.28061224489795916
# Prompt 7 Train Accuracy: 0.4833759590792839
# Prompt 7 Test Accuracy: 0.3163265306122449
# Prompt 8 Train Accuracy: 0.46469833119383824
# Prompt 8 Test Accuracy: 0.3384615384615385
# Prompt 9 Train Accuracy: 0.6120906801007556
# Prompt 9 Test Accuracy: 0.44221105527638194
# Prompt 10 Train Accuracy: 0.5402010050251256
# Prompt 10 Test Accuracy: 0.385
# Optimizing Layer 8 at Context Level 200
# (9361, 1, 512)
# (9361, 512)
# 8    779
# 2    777
# 9    776
# 4    764
# 0    755
# 6    732
# 7    732
# 5    728
# 1    724
# 3    718
# Name: count, dtype: int64
# 2    195
# 8    195
# 9    195
# 4    192
# 0    189
# 7    184
# 6    183
# 5    182
# 1    181
# 3    180
# Name: count, dtype: int64
# 9    632
# 8    628
# 4    620
# 2    605
# 0    591
# 6    588
# 7    584
# 3    584
# 1    581
# 5    575
# Name: count, dtype: int64
# 2    172
# 0    164
# 5    153
# 8    151
# 7    148
# 9    144
# 4    144
# 6    144
# 1    143
# 3    134
# Name: count, dtype: int64
# Train Data Shape:  (7485, 512)
# Test Data Shape:  (1876, 512)
# Optimizer Train Data Shape:  (5988, 512)
# Train Accuracy: 0.49966599866399464
# Test Accuracy: 0.3736673773987207
# Prompt 1 Train Accuracy: 0.5298013245033113
# Prompt 1 Test Accuracy: 0.31216931216931215
# Prompt 2 Train Accuracy: 0.4350828729281768
# Prompt 2 Test Accuracy: 0.30386740331491713
# Prompt 3 Train Accuracy: 0.7117117117117117
# Prompt 3 Test Accuracy: 0.6153846153846154
# Prompt 4 Train Accuracy: 0.26323119777158777
# Prompt 4 Test Accuracy: 0.2
# Prompt 5 Train Accuracy: 0.6465968586387435
# Prompt 5 Test Accuracy: 0.5104166666666666
# Prompt 6 Train Accuracy: 0.3489010989010989
# Prompt 6 Test Accuracy: 0.24725274725274726
# Prompt 7 Train Accuracy: 0.46174863387978143
# Prompt 7 Test Accuracy: 0.3224043715846995
# Prompt 8 Train Accuracy: 0.40710382513661203
# Prompt 8 Test Accuracy: 0.30434782608695654
# Prompt 9 Train Accuracy: 0.6046213093709885
# Prompt 9 Test Accuracy: 0.49743589743589745
# Prompt 10 Train Accuracy: 0.5515463917525774
# Prompt 10 Test Accuracy: 0.38974358974358975
# Optimizing Layer 8 at Context Level 225
# (8394, 1, 512)
# (8394, 512)
# 9    738
# 2    720
# 8    709
# 4    692
# 0    675
# 7    652
# 1    636
# 6    635
# 5    630
# 3    624
# Name: count, dtype: int64
# 9    185
# 2    180
# 8    178
# 4    174
# 0    169
# 7    164
# 1    160
# 6    159
# 5    158
# 3    156
# Name: count, dtype: int64
# 9    604
# 8    563
# 2    562
# 4    548
# 7    524
# 0    522
# 1    520
# 3    515
# 6    509
# 5    501
# Name: count, dtype: int64
# 2    158
# 0    153
# 8    146
# 4    144
# 9    134
# 5    129
# 7    128
# 6    126
# 1    116
# 3    109
# Name: count, dtype: int64
# Train Data Shape:  (6711, 512)
# Test Data Shape:  (1683, 512)
# Optimizer Train Data Shape:  (5368, 512)
# Train Accuracy: 0.5035017136045299
# Test Accuracy: 0.35056446821152704
# Prompt 1 Train Accuracy: 0.5274074074074074
# Prompt 1 Test Accuracy: 0.3431952662721893
# Prompt 2 Train Accuracy: 0.4371069182389937
# Prompt 2 Test Accuracy: 0.25
# Prompt 3 Train Accuracy: 0.7583333333333333
# Prompt 3 Test Accuracy: 0.5388888888888889
# Prompt 4 Train Accuracy: 0.1233974358974359
# Prompt 4 Test Accuracy: 0.07051282051282051
# Prompt 5 Train Accuracy: 0.6777456647398844
# Prompt 5 Test Accuracy: 0.5747126436781609
# Prompt 6 Train Accuracy: 0.273015873015873
# Prompt 6 Test Accuracy: 0.15822784810126583
# Prompt 7 Train Accuracy: 0.5196850393700787
# Prompt 7 Test Accuracy: 0.3710691823899371
# Prompt 8 Train Accuracy: 0.4156441717791411
# Prompt 8 Test Accuracy: 0.21341463414634146
# Prompt 9 Train Accuracy: 0.6022566995768688
# Prompt 9 Test Accuracy: 0.43258426966292135
# Prompt 10 Train Accuracy: 0.6138211382113821
# Prompt 10 Test Accuracy: 0.4756756756756757
# Optimizing Layer 8 at Context Level 250
# (6898, 1, 512)
# (6898, 512)
# 9    648
# 8    624
# 2    621
# 4    581
# 0    548
# 7    522
# 6    501
# 1    495
# 3    492
# 5    483
# Name: count, dtype: int64
# 9    162
# 2    156
# 8    156
# 4    146
# 0    138
# 7    131
# 6    126
# 1    124
# 3    123
# 5    121
# Name: count, dtype: int64
# 9    533
# 8    487
# 2    478
# 4    454
# 7    424
# 0    420
# 6    417
# 3    408
# 1    398
# 5    393
# Name: count, dtype: int64
# 2    143
# 8    137
# 0    128
# 4    127
# 9    115
# 7     98
# 1     97
# 5     90
# 6     84
# 3     84
# Name: count, dtype: int64
# Train Data Shape:  (5515, 512)
# Test Data Shape:  (1383, 512)
# Optimizer Train Data Shape:  (4412, 512)
# Train Accuracy: 0.4542157751586582
# Test Accuracy: 0.3398409255242227
# Prompt 1 Train Accuracy: 0.4854014598540146
# Prompt 1 Test Accuracy: 0.21014492753623187
# Prompt 2 Train Accuracy: 0.35353535353535354
# Prompt 2 Test Accuracy: 0.3064516129032258
# Prompt 3 Train Accuracy: 0.7648953301127214
# Prompt 3 Test Accuracy: 0.6730769230769231
# Prompt 4 Train Accuracy: 0.022357723577235773
# Prompt 4 Test Accuracy: 0.032520325203252036
# Prompt 5 Train Accuracy: 0.6196213425129088
# Prompt 5 Test Accuracy: 0.5068493150684932
# Prompt 6 Train Accuracy: 0.16149068322981366
# Prompt 6 Test Accuracy: 0.0743801652892562
# Prompt 7 Train Accuracy: 0.3972055888223553
# Prompt 7 Test Accuracy: 0.2777777777777778
# Prompt 8 Train Accuracy: 0.20306513409961685
# Prompt 8 Test Accuracy: 0.09923664122137404
# Prompt 9 Train Accuracy: 0.6538461538461539
# Prompt 9 Test Accuracy: 0.532051282051282
# Prompt 10 Train Accuracy: 0.6589506172839507
# Prompt 10 Test Accuracy: 0.49382716049382713
# Optimizing Layer 8 at Context Level 275
# (5137, 1, 512)
# (5137, 512)
# 9    508
# 8    504
# 2    500
# 4    452
# 0    408
# 7    376
# 6    347
# 1    344
# 5    336
# 3    328
# Name: count, dtype: int64
# 9    128
# 8    127
# 2    126
# 4    114
# 0    103
# 7     95
# 1     87
# 6     87
# 5     85
# 3     82
# Name: count, dtype: int64
# 9    414
# 8    406
# 2    393
# 4    357
# 0    307
# 7    307
# 1    282
# 5    273
# 6    272
# 3    271
# Name: count, dtype: int64
# 2    107
# 0    101
# 8     98
# 4     95
# 9     94
# 6     75
# 7     69
# 5     63
# 1     62
# 3     57
# Name: count, dtype: int64
# Train Data Shape:  (4103, 512)
# Test Data Shape:  (1034, 512)
# Optimizer Train Data Shape:  (3282, 512)
# Train Accuracy: 0.36704850109675846
# Test Accuracy: 0.30077369439071566
# Prompt 1 Train Accuracy: 0.13480392156862744
# Prompt 1 Test Accuracy: 0.21359223300970873
# Prompt 2 Train Accuracy: 0.020348837209302327
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.83
# Prompt 3 Test Accuracy: 0.6904761904761905
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.668141592920354
# Prompt 5 Test Accuracy: 0.5350877192982456
# Prompt 6 Train Accuracy: 0.03273809523809524
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.1037463976945245
# Prompt 7 Test Accuracy: 0.04597701149425287
# Prompt 8 Train Accuracy: 0.007978723404255319
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.6706349206349206
# Prompt 9 Test Accuracy: 0.5905511811023622
# Prompt 10 Train Accuracy: 0.6673228346456693
# Prompt 10 Test Accuracy: 0.484375
# Optimizing Layer 8 at Context Level 300
# (3342, 1, 512)
# (3342, 512)
# 9    370
# 8    365
# 2    343
# 4    292
# 0    256
# 7    230
# 6    217
# 1    211
# 5    206
# 3    180
# Name: count, dtype: int64
# 9    93
# 8    92
# 2    86
# 4    73
# 0    64
# 7    58
# 6    55
# 1    53
# 5    52
# 3    46
# Name: count, dtype: int64
# 9    300
# 8    288
# 2    276
# 4    228
# 0    204
# 6    183
# 7    178
# 5    172
# 1    165
# 3    142
# Name: count, dtype: int64
# 8    77
# 9    70
# 2    67
# 4    64
# 0    52
# 7    52
# 1    46
# 3    38
# 5    34
# 6    34
# Name: count, dtype: int64
# Train Data Shape:  (2670, 512)
# Test Data Shape:  (672, 512)
# Optimizer Train Data Shape:  (2136, 512)
# Train Accuracy: 0.33707865168539325
# Test Accuracy: 0.2619047619047619
# Prompt 1 Train Accuracy: 0.015625
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.7142857142857143
# Prompt 3 Test Accuracy: 0.5581395348837209
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.4178082191780822
# Prompt 5 Test Accuracy: 0.2876712328767123
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.7424657534246575
# Prompt 9 Test Accuracy: 0.6304347826086957
# Prompt 10 Train Accuracy: 0.6972972972972973
# Prompt 10 Test Accuracy: 0.5268817204301075
# Optimizing Layer 8 at Context Level 325
# (1890, 1, 512)
# (1890, 512)
# 9    234
# 8    224
# 2    202
# 4    175
# 0    144
# 7    114
# 6    111
# 1    109
# 5    100
# 3     95
# Name: count, dtype: int64
# 9    59
# 8    57
# 2    51
# 4    44
# 0    36
# 7    29
# 1    28
# 6    28
# 5    26
# 3    24
# Name: count, dtype: int64
# 9    191
# 8    175
# 2    159
# 4    137
# 0    116
# 6     90
# 1     90
# 7     87
# 5     84
# 3     77
# Name: count, dtype: int64
# 8    49
# 2    43
# 9    43
# 4    38
# 0    28
# 7    27
# 6    21
# 1    19
# 3    18
# 5    16
# Name: count, dtype: int64
# Train Data Shape:  (1508, 512)
# Test Data Shape:  (382, 512)
# Optimizer Train Data Shape:  (1206, 512)
# Train Accuracy: 0.259946949602122
# Test Accuracy: 0.24083769633507854
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.22772277227722773
# Prompt 3 Test Accuracy: 0.2549019607843137
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.65625
# Prompt 9 Test Accuracy: 0.6491228070175439
# Prompt 10 Train Accuracy: 0.8504273504273504
# Prompt 10 Test Accuracy: 0.711864406779661
# Optimizing Layer 8 at Context Level 350
# (985, 1, 512)
# (985, 512)
# 9    141
# 8    124
# 2    112
# 4     96
# 0     74
# 7     58
# 1     51
# 6     46
# 3     44
# 5     40
# Name: count, dtype: int64
# 9    36
# 8    31
# 2    28
# 4    24
# 0    19
# 7    15
# 1    13
# 6    12
# 3    11
# 5    10
# Name: count, dtype: int64
# 9    111
# 8     97
# 2     95
# 4     71
# 0     58
# 7     46
# 3     40
# 1     39
# 6     36
# 5     35
# Name: count, dtype: int64
# 9    30
# 8    27
# 4    25
# 2    17
# 0    16
# 7    12
# 1    12
# 6    10
# 5     5
# 3     4
# Name: count, dtype: int64
# Train Data Shape:  (786, 512)
# Test Data Shape:  (199, 512)
# Optimizer Train Data Shape:  (628, 512)
# Train Accuracy: 0.17938931297709923
# Test Accuracy: 0.18090452261306533
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 8 at Context Level 375
# (474, 1, 512)
# (474, 512)
# 9    72
# 8    61
# 2    54
# 0    37
# 4    37
# 7    29
# 1    24
# 3    23
# 5    19
# 6    18
# Name: count, dtype: int64
# 9    19
# 8    16
# 2    14
# 0    10
# 4    10
# 7     8
# 1     7
# 3     6
# 5     5
# 6     5
# Name: count, dtype: int64
# 9    59
# 8    53
# 2    40
# 4    33
# 0    28
# 7    20
# 3    18
# 1    17
# 5    16
# 6    15
# Name: count, dtype: int64
# 2    14
# 9    13
# 0     9
# 7     9
# 8     8
# 1     7
# 3     5
# 4     4
# 5     3
# 6     3
# Name: count, dtype: int64
# Train Data Shape:  (374, 512)
# Test Data Shape:  (100, 512)
# Optimizer Train Data Shape:  (299, 512)
# Train Accuracy: 0.1925133689839572
# Test Accuracy: 0.19
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 0.0
# Prompt 9 Test Accuracy: 0.0
# Prompt 10 Train Accuracy: 1.0
# Prompt 10 Test Accuracy: 1.0
# Optimizing Layer 8 at Context Level 400
# (192, 1, 512)
# (192, 512)
# 8    33
# 9    31
# 2    20
# 4    16
# 0    11
# 1    11
# 7    10
# 5     7
# 3     6
# 6     5
# Name: count, dtype: int64
# 8    9
# 9    8
# 2    6
# 4    4
# 0    3
# 1    3
# 7    3
# 3    2
# 5    2
# 6    2
# Name: count, dtype: int64
# 8    29
# 9    24
# 2    15
# 4    14
# 0    10
# 1     8
# 7     7
# 3     5
# 5     4
# 6     4
# Name: count, dtype: int64
# 9    7
# 2    5
# 8    4
# 1    3
# 7    3
# 5    3
# 4    2
# 6    1
# 0    1
# 3    1
# Name: count, dtype: int64
# Train Data Shape:  (150, 512)
# Test Data Shape:  (42, 512)
# Optimizer Train Data Shape:  (120, 512)
# Train Accuracy: 0.22
# Test Accuracy: 0.21428571428571427
# Prompt 1 Train Accuracy: 0.0
# Prompt 1 Test Accuracy: 0.0
# Prompt 2 Train Accuracy: 0.0
# Prompt 2 Test Accuracy: 0.0
# Prompt 3 Train Accuracy: 0.0
# Prompt 3 Test Accuracy: 0.0
# Prompt 4 Train Accuracy: 0.0
# Prompt 4 Test Accuracy: 0.0
# Prompt 5 Train Accuracy: 0.0
# Prompt 5 Test Accuracy: 0.0
# Prompt 6 Train Accuracy: 0.0
# Prompt 6 Test Accuracy: 0.0
# Prompt 7 Train Accuracy: 0.0
# Prompt 7 Test Accuracy: 0.0
# Prompt 8 Train Accuracy: 0.0
# Prompt 8 Test Accuracy: 0.0
# Prompt 9 Train Accuracy: 1.0
# Prompt 9 Test Accuracy: 1.0
# Prompt 10 Train Accuracy: 0.0
# Prompt 10 Test Accuracy: 0.0
# Optimizing Layer 8 at Context Level 425
# (73, 1, 512)
# (73, 512)
