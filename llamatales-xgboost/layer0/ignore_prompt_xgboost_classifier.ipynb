# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

from xgboost import XGBClassifier

import csv

import cupy as cp

# %%
df = pd.read_csv("../../llamatales/story_dataset.csv")
df
# Out:
#       prompt_id                                 prompt  \
# 0             1    Once upon a time there was a dragon
# 1             1    Once upon a time there was a dragon
# 2             1    Once upon a time there was a dragon
# 3             1    Once upon a time there was a dragon
# 4             1    Once upon a time there was a dragon
# ...         ...                                    ...
# 9995         10  Once upon a time there was a poor boy
# 9996         10  Once upon a time there was a poor boy
# 9997         10  Once upon a time there was a poor boy
# 9998         10  Once upon a time there was a poor boy
# 9999         10  Once upon a time there was a poor boy
#
#                                                   story  \
# 0     Once upon a time there was a dragon named Blaz...
# 1     Once upon a time there was a dragon named Spar...
# 2     Once upon a time there was a dragon named Scor...
# 3     Once upon a time there was a dragon. The drago...
# 4     Once upon a time there was a dragon. The drago...
# ...                                                 ...
# 9995  Once upon a time there was a poor boy named Ti...
# 9996  Once upon a time there was a poor boy named Ti...
# 9997  Once upon a time there was a poor boy named Ti...
# 9998  Once upon a time there was a poor boy named Ti...
# 9999  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story  len_new_story
# 0      ./hidden_states/prompt_1.npz                  270            271
# 1      ./hidden_states/prompt_1.npz                  349            350
# 2      ./hidden_states/prompt_1.npz                  278            278
# 3      ./hidden_states/prompt_1.npz                  117            118
# 4      ./hidden_states/prompt_1.npz                  129            130
# ...                             ...                  ...            ...
# 9995  ./hidden_states/prompt_10.npz                  289            290
# 9996  ./hidden_states/prompt_10.npz                  119            119
# 9997  ./hidden_states/prompt_10.npz                  127            128
# 9998  ./hidden_states/prompt_10.npz                  441            441
# 9999  ./hidden_states/prompt_10.npz                  520            521
#
# [10000 rows x 6 columns]

# %%
hidden_states_by_layer = {}
NUM_PROMPTS = 10
# NUM_PROMPTS = 2

for prompt_id in range(1, NUM_PROMPTS + 1):
    with np.load(f'../../llamatales/hidden_states/prompt_{prompt_id}.npz') as loaded_data:
        for i in tqdm(range(1000)):
            curr_hidden_states = loaded_data[f"arr_{i}"][0]
            # print(curr_hidden_states.shape)
            
            #By layer
            for layer in range(1):
                curr_layer_hidden_states = curr_hidden_states[layer][0].astype('float32') #FAISS expects data in type float32 instead of float64 - saves memory too!
                # print(curr_layer_hidden_states.shape)
                
                if(f"layer_{layer}" in hidden_states_by_layer):
                    hidden_states_by_layer[f"layer_{layer}"].append(curr_layer_hidden_states)
                else:
                    hidden_states_by_layer[f"layer_{layer}"] = [curr_layer_hidden_states]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:05<00:00,  3.27it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:57<00:00,  4.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:25<00:00,  4.87it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:30<00:00,  3.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:04<00:00,  3.29it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:59<00:00,  4.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:08<00:00,  4.02it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [03:53<00:00,  4.28it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:16<00:00,  3.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [04:37<00:00,  3.60it/s]

# %%
layer_hs_array = hidden_states_by_layer["layer_0"]
print(layer_hs_array[0].shape)
print(layer_hs_array[1].shape)
# Out:
# (270, 512)
# (349, 512)

# %%
min_story_len = min(df["len_generated_story"])
min_story_len
# Out:
# 21

# %%
max_story_len = max(df[:NUM_PROMPTS*1000]["len_generated_story"])

# %%
max_new_story_len = max(df["len_new_story"])

# %%
max_new_story_len = max(df[:NUM_PROMPTS*1000]["len_new_story"])

# %%
max_new_story_len
# Out:
# 523

# %%
df[df["len_generated_story"] >= max_story_len].shape
# Out:
# (13, 6)

# %%
df[df["len_new_story"] >= max_new_story_len]
# Out:
#       prompt_id                                    prompt  \
# 2360          3  Once upon a time there were two children
# 2628          3  Once upon a time there were two children
# 7795          8         Once upon a time there was a wolf
# 9178         10     Once upon a time there was a poor boy
# 9201         10     Once upon a time there was a poor boy
# 9270         10     Once upon a time there was a poor boy
# 9313         10     Once upon a time there was a poor boy
# 9603         10     Once upon a time there was a poor boy
# 9626         10     Once upon a time there was a poor boy
# 9685         10     Once upon a time there was a poor boy
# 9787         10     Once upon a time there was a poor boy
# 9839         10     Once upon a time there was a poor boy
# 9991         10     Once upon a time there was a poor boy
#
#                                                   story  \
# 2360  Once upon a time there were two children, Emma...
# 2628  Once upon a time there were two children named...
# 7795  Once upon a time there was a wolf named Max. M...
# 9178  Once upon a time there was a poor boy named Ti...
# 9201  Once upon a time there was a poor boy named Ti...
# 9270  Once upon a time there was a poor boy named Ti...
# 9313  Once upon a time there was a poor boy named Ti...
# 9603  Once upon a time there was a poor boy named Ti...
# 9626  Once upon a time there was a poor boy named Ti...
# 9685  Once upon a time there was a poor boy named Ti...
# 9787  Once upon a time there was a poor boy named Ti...
# 9839  Once upon a time there was a poor boy named Ti...
# 9991  Once upon a time there was a poor boy named Ti...
#
#                   hidden_state_file  len_generated_story  len_new_story
# 2360   ./hidden_states/prompt_3.npz                  522            523
# 2628   ./hidden_states/prompt_3.npz                  522            523
# 7795   ./hidden_states/prompt_8.npz                  522            523
# 9178  ./hidden_states/prompt_10.npz                  522            523
# 9201  ./hidden_states/prompt_10.npz                  522            523
# 9270  ./hidden_states/prompt_10.npz                  522            523
# 9313  ./hidden_states/prompt_10.npz                  522            523
# 9603  ./hidden_states/prompt_10.npz                  522            523
# 9626  ./hidden_states/prompt_10.npz                  522            523
# 9685  ./hidden_states/prompt_10.npz                  522            523
# 9787  ./hidden_states/prompt_10.npz                  522            523
# 9839  ./hidden_states/prompt_10.npz                  522            523
# 9991  ./hidden_states/prompt_10.npz                  522            523

# %%
max(df[:NUM_PROMPTS*1000]["len_new_story"])
# Out:
# 523

# %%
hs_shapes = []
for i in range(len(layer_hs_array)):
    hs_shapes.append(layer_hs_array[i].shape[0])

# %%
np.array(hs_shapes)[9685]
# Out:
# 522

# %%
def safe_split(total, train_ratio=0.8):
    train = int(train_ratio * total)   # floor
    test  = total - train              # leftover
    return train, test

def build_dataset(curr_context_level_hs, curr_labels, train_ratio=0.8):
    """
    Groups samples by prompt_id, splits safely into train/test,
    and returns X_train, y_train, X_test, y_test.
    """

    unique_ids = sorted(set(curr_labels))

    X_train_list = []
    X_test_list = []
    y_train_list = []
    y_test_list = []

    for pid in unique_ids:

        # get samples for this prompt id
        mask = (curr_labels == pid)
        X_pid = curr_context_level_hs[mask]
        y_pid = curr_labels[mask]

        total = len(X_pid)
        train_n, test_n = safe_split(total, train_ratio)

        # split
        X_train_list.append(X_pid[:train_n])
        y_train_list.append(y_pid[:train_n])

        X_test_list.append(X_pid[train_n:])
        y_test_list.append(y_pid[train_n:])

    # concatenate all prompt-id blocks
    X_train = np.concatenate(X_train_list, axis=0)
    y_train = np.concatenate(y_train_list, axis=0)
    X_test  = np.concatenate(X_test_list, axis=0)
    y_test  = np.concatenate(y_test_list, axis=0)

    # return cp.array(X_train), cp.array(y_train), cp.array(X_test), cp.array(y_test)
    return X_train, y_train, X_test, y_test

# %%
#Context-level analysis
# min_story_len = min(df["len_new_story"])
max_story_len = max(df[:NUM_PROMPTS*1000]["len_new_story"]) #save hidden states when generating new story - length of hidden states is of the old story (522)

with open("results-3.csv", "w+", newline='') as csvfile:
    csv_writer = csv.writer(csvfile, delimiter=',')
    csv_writer.writerow(['Context Level', 'Accuracy'])

for context_level in range(11, max_story_len):
    curr_context_level_hs = []
    curr_labels = []
    
    curr_hs_shapes = []
    for i in range(len(layer_hs_array)):
        # print(np.array(layer_hs_array[i][:context_level]).shape) #see if taking context level more than available causes error?
        if(layer_hs_array[i].shape[0] < context_level):
            # print(i) #see which samples have less tokens than current context level
            continue
        else:
            layer_hs_upto_context = layer_hs_array[i][10:context_level]
            curr_hs_shapes.append(layer_hs_array[i].shape[0])
            curr_context_level_hs.append(np.array(layer_hs_upto_context).flatten())
            curr_labels.append(df.iloc[i].prompt_id)
    
    curr_context_level_hs = np.array(curr_context_level_hs).astype('float32')
    # print([i for i in range(len(curr_context_level_hs)) if curr_context_level_hs[i].shape[0] < i]) #see if any residuals escape screening
    # print(curr_context_level_hs.shape) #print shape without samples less than context level
    curr_labels = np.array(curr_labels) - 1
    unique_ids = sorted(set(curr_labels))
    
    if np.var(curr_context_level_hs) < 1e-6:
        print("Skipped context level: ", context_level)
        continue

    if(len(unique_ids) < 10): break
    
    X_train, y_train, X_test, y_test = build_dataset(curr_context_level_hs, curr_labels)

    # from sklearn.preprocessing import StandardScaler
    # scaler = StandardScaler()
    # X_train_scaled = scaler.fit_transform(X_train)
    # X_test_scaled = scaler.transform(X_test)

    # from sklearn.decomposition import PCA
    # pca = PCA(n_components=0.95)
    
    # X_train_pca = pca.fit_transform(X_train_scaled)
    # X_test_pca = pca.transform(X_test_scaled)

    # print("Train Data Shape: ", X_train_pca.shape)
    # # print("Train Labels Shape: ", y_train.shape)
    # print("Test Data Shape: ", X_test_pca.shape)
    # # print("Test Labels Shape: ", y_test.shape)

    # X_train_pca = cp.array(X_train_pca)
    # y_train = cp.array(y_train)
    # X_test_pca = cp.array(X_test_pca)
    # y_test = cp.array(y_test)

    print("Train Data Shape: ", X_train.shape)
#     print("Train Labels Shape: ", y_train.shape)
    print("Test Data Shape: ", X_test.shape)
#     print("Test Labels Shape: ", y_test.shape)
    
    X_train = cp.array(X_train)
    y_train = cp.array(y_train)
    X_test = cp.array(X_test)
    y_test = cp.array(y_test)
    
    # classifier = XGBClassifier(seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids))
    # classifier = XGBClassifier(seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids), tree_method='gpu_hist', predictor='gpu_predictor')

    classifier = XGBClassifier(seed = 42, objective = 'multi:softmax', eval_metric = "merror", num_class = len(unique_ids), tree_method='hist', device='cuda')
    
    classifier.fit(X_train, y_train)
    preds = classifier.predict(X_test)

    # classifier.fit(X_train_pca, y_train)
    # preds = classifier.predict(X_test_pca)
    
    
#     print("Predictions Shape: ", preds.shape)
    
#     print("Unique Preds: ", pd.Series(preds).value_counts())
#     print("Unique Test Labels: ", pd.Series(y_test).value_counts())
    accuracy = np.mean(cp.array(preds) == y_test)
    print(f"Accuracy: {accuracy}")
    with open("results-3.csv", "a+", newline='') as csvfile:
        csv_writer = csv.writer(csvfile, delimiter=',')
        csv_writer.writerow([X_train.shape[1] // 512, accuracy])
    
    # print(max(curr_hs_shapes))
# Out:
# Train Data Shape:  (8000, 38)
# Test Data Shape:  (2000, 38)
# Accuracy: 0.681
# Train Data Shape:  (8000, 65)
# Test Data Shape:  (2000, 65)
# Accuracy: 0.733
# Train Data Shape:  (8000, 111)
# Test Data Shape:  (2000, 111)
# Accuracy: 0.7665
# Train Data Shape:  (8000, 177)
# Test Data Shape:  (2000, 177)
# Accuracy: 0.82
# Train Data Shape:  (8000, 264)
# Test Data Shape:  (2000, 264)
# Accuracy: 0.845
# Train Data Shape:  (8000, 371)
# Test Data Shape:  (2000, 371)
# Accuracy: 0.868
# Train Data Shape:  (8000, 494)
# Test Data Shape:  (2000, 494)
# Accuracy: 0.861
# Train Data Shape:  (8000, 623)
# Test Data Shape:  (2000, 623)
# Accuracy: 0.863
# Train Data Shape:  (8000, 760)
# Test Data Shape:  (2000, 760)
# Accuracy: 0.8835
# Train Data Shape:  (8000, 906)
# Test Data Shape:  (2000, 906)
# Accuracy: 0.883
# Train Data Shape:  (8000, 1062)
# Test Data Shape:  (2000, 1062)
# Accuracy: 0.884
# Train Data Shape:  (7999, 1221)
# Test Data Shape:  (2000, 1221)
# Accuracy: 0.893
# Train Data Shape:  (7999, 1382)
# Test Data Shape:  (2000, 1382)
# Accuracy: 0.888
# Train Data Shape:  (7999, 1543)
# Test Data Shape:  (2000, 1543)
# Accuracy: 0.892
# Train Data Shape:  (7999, 1700)
# Test Data Shape:  (2000, 1700)
# Accuracy: 0.883
# Train Data Shape:  (7999, 1858)
# Test Data Shape:  (2000, 1858)
# Accuracy: 0.877
# Train Data Shape:  (7999, 2012)
# Test Data Shape:  (2000, 2012)
# Accuracy: 0.888
# Train Data Shape:  (7998, 2165)
# Test Data Shape:  (2000, 2165)
# Accuracy: 0.892
# Train Data Shape:  (7998, 2313)
# Test Data Shape:  (2000, 2313)
# Accuracy: 0.879
# Train Data Shape:  (7998, 2460)
# Test Data Shape:  (2000, 2460)
# Accuracy: 0.877
# Train Data Shape:  (7998, 2603)
# Test Data Shape:  (2000, 2603)
# Accuracy: 0.8795
# Train Data Shape:  (7998, 2743)
# Test Data Shape:  (2000, 2743)
# Accuracy: 0.87
# Train Data Shape:  (7998, 2881)
# Test Data Shape:  (2000, 2881)
# Accuracy: 0.865
# Train Data Shape:  (7997, 3012)
# Accuracy: 0.774074074074074
# Train Data Shape:  (4299, 3732)
# Test Data Shape:  (1080, 3732)
# Accuracy: 0.7601851851851852
# Train Data Shape:  (4299, 3733)
# Test Data Shape:  (1080, 3733)
# Accuracy: 0.7694444444444445
# Train Data Shape:  (4299, 3733)
# Test Data Shape:  (1080, 3733)
# Accuracy: 0.7824074074074074
# Train Data Shape:  (4299, 3734)
# Test Data Shape:  (1080, 3734)
# Accuracy: 0.7592592592592593
# Train Data Shape:  (4299, 3735)
# Test Data Shape:  (1080, 3735)
# Accuracy: 0.7675925925925926
# Train Data Shape:  (4299, 3736)
# Test Data Shape:  (1080, 3736)
# Accuracy: 0.7731481481481481
# Train Data Shape:  (4299, 3737)
# Test Data Shape:  (1080, 3737)
# Accuracy: 0.7768518518518519
# Train Data Shape:  (4299, 3738)
# Test Data Shape:  (1080, 3738)
# Accuracy: 0.7657407407407407
# Train Data Shape:  (4299, 3739)
# Test Data Shape:  (1080, 3739)
# Accuracy: 0.775
# Train Data Shape:  (4299, 3740)
# Test Data Shape:  (1080, 3740)
# Accuracy: 0.7666666666666667
# Train Data Shape:  (4299, 3741)
# Test Data Shape:  (1080, 3741)
# Accuracy: 0.7620370370370371
# Train Data Shape:  (4299, 3742)
# Test Data Shape:  (1080, 3742)
# Accuracy: 0.7638888888888888
# Train Data Shape:  (4299, 3744)
# Test Data Shape:  (1080, 3744)
# Accuracy: 0.7564814814814815
# Train Data Shape:  (4299, 3745)
# Test Data Shape:  (1080, 3745)
# Accuracy: 0.7620370370370371
# Train Data Shape:  (4299, 3746)
# Test Data Shape:  (1080, 3746)
# Accuracy: 0.7537037037037037
# Train Data Shape:  (4299, 3746)
# Test Data Shape:  (1080, 3746)
# Accuracy: 0.762962962962963
# Train Data Shape:  (4299, 3747)
# Test Data Shape:  (1080, 3747)
# Accuracy: 0.7574074074074074
# Train Data Shape:  (4299, 3748)
# Test Data Shape:  (1080, 3748)
# Accuracy: 0.7527777777777778
# Train Data Shape:  (4299, 3748)
# Test Data Shape:  (1080, 3748)
# Accuracy: 0.7620370370370371
# Train Data Shape:  (4299, 3749)
# Test Data Shape:  (1080, 3749)
# Accuracy: 0.7444444444444445
# Train Data Shape:  (4299, 3750)
# Test Data Shape:  (1080, 3750)
# Accuracy: 0.7592592592592593
# Train Data Shape:  (4299, 3750)
# Test Data Shape:  (1080, 3750)
# Accuracy: 0.7537037037037037
# Train Data Shape:  (4299, 3751)
# Test Data Shape:  (1080, 3751)
# Accuracy: 0.7527777777777778
# Train Data Shape:  (4299, 3752)
# Test Data Shape:  (1080, 3752)
# Accuracy: 0.7555555555555555
# Train Data Shape:  (4299, 3753)
# Test Data Shape:  (1080, 3753)
# Accuracy: 0.7555555555555555
# Train Data Shape:  (4299, 3753)
# Test Data Shape:  (1080, 3753)
# Accuracy: 0.7388888888888889
# Train Data Shape:  (4299, 3754)
# Test Data Shape:  (1080, 3754)
# Accuracy: 0.7583333333333333
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7509259259259259
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7490740740740741
# Train Data Shape:  (4299, 3756)
# Test Data Shape:  (1080, 3756)
# Accuracy: 0.7481481481481481
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.7481481481481481
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.7212962962962963
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.737037037037037
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.737037037037037
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.7407407407407407
# Train Data Shape:  (4299, 3756)
# Test Data Shape:  (1080, 3756)
# Accuracy: 0.7388888888888889
# Train Data Shape:  (4299, 3756)
# Test Data Shape:  (1080, 3756)
# Accuracy: 0.7324074074074074
# Train Data Shape:  (4299, 3756)
# Test Data Shape:  (1080, 3756)
# Accuracy: 0.7231481481481481
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7379629629629629
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7342592592592593
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7388888888888889
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7231481481481481
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7129629629629629
# Train Data Shape:  (4299, 3755)
# Test Data Shape:  (1080, 3755)
# Accuracy: 0.7287037037037037
# Train Data Shape:  (4299, 3756)
# Test Data Shape:  (1080, 3756)
# Accuracy: 0.7342592592592593
# Train Data Shape:  (4299, 3757)
# Test Data Shape:  (1080, 3757)
# Accuracy: 0.7296296296296296
# Train Data Shape:  (4299, 3758)
# Test Data Shape:  (1080, 3758)
# Accuracy: 0.725
# Train Data Shape:  (4299, 3759)
# Test Data Shape:  (1080, 3759)
# Accuracy: 0.725925925925926
# Train Data Shape:  (4299, 3760)
# Test Data Shape:  (1080, 3760)
# Accuracy: 0.725925925925926
# Train Data Shape:  (4299, 3761)
# Test Data Shape:  (1080, 3761)
# Accuracy: 0.7305555555555555
# Train Data Shape:  (4299, 3762)
# Test Data Shape:  (1080, 3762)
# Accuracy: 0.7435185185185185
# Train Data Shape:  (4299, 3763)
# Test Data Shape:  (1080, 3763)
# Accuracy: 0.7277777777777777
# Train Data Shape:  (4299, 3764)
# Test Data Shape:  (1080, 3764)
# Accuracy: 0.7388888888888889
# Train Data Shape:  (4299, 3765)
# Test Data Shape:  (1080, 3765)
# Accuracy: 0.7342592592592593
# Train Data Shape:  (4299, 3766)
# Test Data Shape:  (1080, 3766)
# Accuracy: 0.7425925925925926
# Train Data Shape:  (4299, 3768)
# Test Data Shape:  (1080, 3768)
# Accuracy: 0.725
# Test Data Shape:  (1077, 3799)
# Accuracy: 0.7418755803156918
# Train Data Shape:  (4295, 3799)
# Test Data Shape:  (1077, 3799)
# Accuracy: 0.7260909935004642
# Train Data Shape:  (4294, 3799)
# Test Data Shape:  (1077, 3799)
# Accuracy: 0.7465181058495822
# Train Data Shape:  (4294, 3800)
# Test Data Shape:  (1077, 3800)
# Accuracy: 0.7288765088207985
# Train Data Shape:  (4293, 3800)
# Test Data Shape:  (1077, 3800)
# Accuracy: 0.7390900649953575
# Train Data Shape:  (4292, 3801)
# Test Data Shape:  (1077, 3801)
# Accuracy: 0.7455896007428041
# Train Data Shape:  (4292, 3802)
# Test Data Shape:  (1077, 3802)
# Accuracy: 0.744661095636026
# Train Data Shape:  (4291, 3802)
# Test Data Shape:  (1077, 3802)
# Accuracy: 0.7428040854224698
# Train Data Shape:  (4291, 3803)
# Test Data Shape:  (1077, 3803)
# Accuracy: 0.734447539461467
# Train Data Shape:  (4291, 3804)
# Test Data Shape:  (1077, 3804)
# Accuracy: 0.7288765088207985
# Train Data Shape:  (4290, 3804)
# Test Data Shape:  (1077, 3804)
# Accuracy: 0.7353760445682451
# Train Data Shape:  (4288, 3803)
# Test Data Shape:  (1076, 3803)
# Accuracy: 0.7276951672862454
# Train Data Shape:  (4288, 3804)
# Test Data Shape:  (1076, 3804)
# Accuracy: 0.7425650557620818
# Train Data Shape:  (4287, 3804)
# Test Data Shape:  (1076, 3804)
# Accuracy: 0.7407063197026023
# Train Data Shape:  (4286, 3804)
# Test Data Shape:  (1076, 3804)
# Accuracy: 0.7146840148698885
# Train Data Shape:  (4284, 3804)
# Test Data Shape:  (1076, 3804)
# Accuracy: 0.7425650557620818
# Train Data Shape:  (4284, 3805)
# Test Data Shape:  (1076, 3805)
# Accuracy: 0.741635687732342
# Train Data Shape:  (4283, 3805)
# Test Data Shape:  (1076, 3805)
# Accuracy: 0.7276951672862454
# Train Data Shape:  (4282, 3805)
# Test Data Shape:  (1076, 3805)
# Accuracy: 0.7304832713754646
# Train Data Shape:  (4280, 3804)
# Test Data Shape:  (1076, 3804)
# Accuracy: 0.7397769516728625
# Train Data Shape:  (4279, 3804)
# Test Data Shape:  (1075, 3804)
# Accuracy: 0.7386046511627907
# Train Data Shape:  (4273, 3800)
# Test Data Shape:  (1074, 3800)
# Accuracy: 0.7392923649906891
# Train Data Shape:  (4271, 3799)
# Test Data Shape:  (1074, 3799)
# Accuracy: 0.7374301675977654
# Train Data Shape:  (4269, 3798)
# Test Data Shape:  (1073, 3798)
# Accuracy: 0.7418452935694315
# Train Data Shape:  (4264, 3795)
# Test Data Shape:  (1073, 3795)
# Accuracy: 0.7483690587138863
# Train Data Shape:  (4261, 3793)
# Test Data Shape:  (1072, 3793)
# Accuracy: 0.7509328358208955
# Train Data Shape:  (4254, 3788)
# Test Data Shape:  (1070, 3788)
# Accuracy: 0.7439252336448599
# Train Data Shape:  (4251, 3786)
# Test Data Shape:  (1070, 3786)
# Accuracy: 0.72803738317757
# Train Data Shape:  (4250, 3786)
# Test Data Shape:  (1068, 3786)
# Train Data Shape:  (3815, 3431)
# Test Data Shape:  (960, 3431)
# Accuracy: 0.7270833333333333
# Train Data Shape:  (3794, 3413)
# Test Data Shape:  (952, 3413)
# Accuracy: 0.7111344537815126
# Train Data Shape:  (3771, 3393)
# Test Data Shape:  (946, 3393)
# Accuracy: 0.7230443974630021
# Train Data Shape:  (3752, 3377)
# Test Data Shape:  (942, 3377)
# Accuracy: 0.7250530785562632
# Train Data Shape:  (3718, 3348)
# Test Data Shape:  (933, 3348)
# Accuracy: 0.7234726688102894
# Train Data Shape:  (3685, 3320)
# Test Data Shape:  (928, 3320)
# Accuracy: 0.7262931034482759
# Train Data Shape:  (3652, 3291)
# Test Data Shape:  (916, 3291)
# Accuracy: 0.7161572052401747
# Train Data Shape:  (3626, 3269)
# Test Data Shape:  (909, 3269)
# Accuracy: 0.7194719471947195
# Train Data Shape:  (3598, 3245)
# Test Data Shape:  (904, 3245)
# Accuracy: 0.7168141592920354
# Train Data Shape:  (3567, 3218)
# Test Data Shape:  (898, 3218)
# Accuracy: 0.7149220489977728
# Train Data Shape:  (3540, 3195)
# Test Data Shape:  (889, 3195)
# Accuracy: 0.7210348706411699
# Train Data Shape:  (3515, 3174)
# Test Data Shape:  (885, 3174)
# Accuracy: 0.7141242937853107
# Train Data Shape:  (3485, 3148)
# Test Data Shape:  (874, 3148)
# Accuracy: 0.7116704805491991
# Train Data Shape:  (3446, 3114)
# Test Data Shape:  (866, 3114)
# Accuracy: 0.6997690531177829
# Train Data Shape:  (3416, 3088)
# Test Data Shape:  (860, 3088)
# Accuracy: 0.7023255813953488
# Train Data Shape:  (3392, 3068)
# Test Data Shape:  (852, 3068)
# Accuracy: 0.7183098591549296
# Train Data Shape:  (3369, 3048)
# Test Data Shape:  (846, 3048)
# Accuracy: 0.7092198581560284
# Train Data Shape:  (3342, 3024)
# Test Data Shape:  (841, 3024)
# Accuracy: 0.7110582639714625
# Train Data Shape:  (3317, 3003)
# Test Data Shape:  (832, 3003)
# Accuracy: 0.6995192307692307
# Train Data Shape:  (3292, 2981)
# Test Data Shape:  (830, 2981)
# Accuracy: 0.7156626506024096
# Train Data Shape:  (3267, 2959)
# Test Data Shape:  (822, 2959)
# Accuracy: 0.7128953771289538
# Train Data Shape:  (3242, 2938)
# Test Data Shape:  (815, 2938)
# Accuracy: 0.7288343558282209
# Train Data Shape:  (3209, 2909)
# Test Data Shape:  (808, 2909)
# Accuracy: 0.7042079207920792
# Train Data Shape:  (3180, 2884)
# Test Data Shape:  (801, 2884)
# Accuracy: 0.7066167290886392
# Train Data Shape:  (3154, 2861)
# Test Data Shape:  (793, 2861)
# Accuracy: 0.7061790668348046
# Train Data Shape:  (3111, 2823)
# Test Data Shape:  (783, 2823)
# Accuracy: 0.7088122605363985
# Train Data Shape:  (3071, 2788)
# Test Data Shape:  (774, 2788)
# Accuracy: 0.7054263565891473
# Train Data Shape:  (3052, 2772)
# Test Data Shape:  (767, 2772)
# Accuracy: 0.7131681877444589
# Train Data Shape:  (3029, 2752)
# Test Data Shape:  (763, 2752)
# Accuracy: 0.7142857142857143
# Train Data Shape:  (3013, 2738)
# Test Data Shape:  (759, 2738)
# Accuracy: 0.6903820816864296
# Train Data Shape:  (3000, 2726)
# Test Data Shape:  (755, 2726)
# Accuracy: 0.7006622516556291
# Train Data Shape:  (2985, 2713)
# Test Data Shape:  (752, 2713)
# Accuracy: 0.7101063829787234
# Train Data Shape:  (2969, 2699)
# Test Data Shape:  (748, 2699)
# Accuracy: 0.6991978609625669
# Train Data Shape:  (2959, 2691)
# Test Data Shape:  (744, 2691)
# Accuracy: 0.7190860215053764
# Train Data Shape:  (2949, 2682)
# Test Data Shape:  (742, 2682)
# Accuracy: 0.7008086253369272
# Train Data Shape:  (2936, 2671)
# Test Data Shape:  (741, 2671)
# Accuracy: 0.7044534412955465
# Train Data Shape:  (2929, 2665)
# Test Data Shape:  (736, 2665)
# Accuracy: 0.7146739130434783
# Train Data Shape:  (2915, 2652)
# Test Data Shape:  (735, 2652)
# Accuracy: 0.708843537414966
# Train Data Shape:  (2905, 2644)
# Test Data Shape:  (732, 2644)
# Accuracy: 0.6830601092896175
# Train Data Shape:  (2893, 2633)
# Test Data Shape:  (730, 2633)
# Accuracy: 0.6958904109589041
# Train Data Shape:  (2883, 2625)
# Test Data Shape:  (729, 2625)
# Accuracy: 0.7064471879286695
# Train Data Shape:  (2877, 2619)
# Test Data Shape:  (724, 2619)
# Accuracy: 0.7002762430939227
# Train Data Shape:  (2871, 2614)
# Test Data Shape:  (723, 2614)
# Accuracy: 0.7026279391424619
# Train Data Shape:  (2860, 2605)
# Test Data Shape:  (720, 2605)
# Accuracy: 0.7111111111111111
# Train Data Shape:  (2854, 2600)
# Test Data Shape:  (717, 2600)
# Accuracy: 0.6959553695955369
# Train Data Shape:  (2844, 2591)
# Test Data Shape:  (715, 2591)
# Accuracy: 0.6923076923076923
# Train Data Shape:  (2837, 2585)
# Test Data Shape:  (714, 2585)
# Accuracy: 0.7142857142857143
# Train Data Shape:  (2828, 2577)
# Test Data Shape:  (713, 2577)
# Accuracy: 0.7138849929873773
# Train Data Shape:  (2817, 2568)
# Test Data Shape:  (710, 2568)
# Accuracy: 0.723943661971831
# Train Data Shape:  (2809, 2561)
# Test Data Shape:  (707, 2561)
# Accuracy: 0.7001414427157001
# Train Data Shape:  (2799, 2552)
# Test Data Shape:  (706, 2552)
# Accuracy: 0.7082152974504249
# Train Data Shape:  (2789, 2543)
# Test Data Shape:  (701, 2543)
# Accuracy: 0.6961483594864479
# Train Data Shape:  (2777, 2533)
# Test Data Shape:  (698, 2533)
# Accuracy: 0.7134670487106017
# Train Data Shape:  (2762, 2519)
# Test Data Shape:  (697, 2519)
# Accuracy: 0.7116212338593975
# Train Data Shape:  (2754, 2512)
# Test Data Shape:  (695, 2512)
# Accuracy: 0.7050359712230215
# Train Data Shape:  (2745, 2505)
# Test Data Shape:  (693, 2505)
# Accuracy: 0.7085137085137085
# Train Data Shape:  (2741, 2501)
# Test Data Shape:  (690, 2501)
# Accuracy: 0.7159420289855073
# Train Data Shape:  (2733, 2494)
# Test Data Shape:  (687, 2494)
# Accuracy: 0.6943231441048034
# Train Data Shape:  (2728, 2490)
# Test Data Shape:  (687, 2490)
# Accuracy: 0.7030567685589519
# Train Data Shape:  (2720, 2483)
# Test Data Shape:  (684, 2483)
# Accuracy: 0.7076023391812866
# Train Data Shape:  (2712, 2476)
# Test Data Shape:  (682, 2476)
# Accuracy: 0.6994134897360704
# Train Data Shape:  (2709, 2473)
# Test Data Shape:  (682, 2473)
# Accuracy: 0.7140762463343109
# Train Data Shape:  (2699, 2464)
# Test Data Shape:  (681, 2464)
# Accuracy: 0.7019089574155654
# Train Data Shape:  (2695, 2461)
# Test Data Shape:  (680, 2461)
# Accuracy: 0.7014705882352941
# Train Data Shape:  (2688, 2455)
# Test Data Shape:  (678, 2455)
# Accuracy: 0.7064896755162242
# Train Data Shape:  (2683, 2451)
# Test Data Shape:  (676, 2451)
# Accuracy: 0.7026627218934911
# Train Data Shape:  (2677, 2445)
# Test Data Shape:  (672, 2445)
# Accuracy: 0.7217261904761905
# Train Data Shape:  (2672, 2441)
# Test Data Shape:  (671, 2441)
# Accuracy: 0.7093889716840537
# Train Data Shape:  (2671, 2440)
# Test Data Shape:  (671, 2440)
# Accuracy: 0.7034277198211625
# Train Data Shape:  (2669, 2439)
# Test Data Shape:  (671, 2439)
# Accuracy: 0.7049180327868853
# Train Data Shape:  (2669, 2439)
# Test Data Shape:  (671, 2439)
# Accuracy: 0.6974664679582713
# Train Data Shape:  (2665, 2435)
# Test Data Shape:  (671, 2435)
# Accuracy: 0.6795827123695977
# Train Data Shape:  (2665, 2436)
# Test Data Shape:  (671, 2436)
# Accuracy: 0.684053651266766
# Train Data Shape:  (2663, 2434)
# Test Data Shape:  (671, 2434)
# Accuracy: 0.6885245901639344
# Train Data Shape:  (2661, 2432)
# Test Data Shape:  (670, 2432)
# Accuracy: 0.6880597014925374
# Train Data Shape:  (2660, 2432)
# Test Data Shape:  (670, 2432)
# Accuracy: 0.6865671641791045
# Train Data Shape:  (2660, 2432)
# Test Data Shape:  (670, 2432)
# Accuracy: 0.7119402985074627
# Train Data Shape:  (2658, 2430)
# Test Data Shape:  (670, 2430)
# Accuracy: 0.6940298507462687
# Train Data Shape:  (2656, 2428)
# Test Data Shape:  (670, 2428)
# Accuracy: 0.6985074626865672
# Train Data Shape:  (2655, 2428)
# Test Data Shape:  (670, 2428)
# Accuracy: 0.6880597014925374
# Train Data Shape:  (2653, 2426)
# Test Data Shape:  (669, 2426)
# Accuracy: 0.695067264573991
# Train Data Shape:  (2651, 2424)
# Test Data Shape:  (669, 2424)
# Accuracy: 0.7115097159940209
# Train Data Shape:  (2651, 2424)
# Test Data Shape:  (669, 2424)
# Accuracy: 0.7085201793721974
# Train Data Shape:  (2650, 2424)
# Test Data Shape:  (669, 2424)
# Accuracy: 0.7144992526158446
# Train Data Shape:  (2648, 2422)
# Test Data Shape:  (668, 2422)
# Accuracy: 0.7065868263473054
# Train Data Shape:  (2647, 2421)
# Test Data Shape:  (667, 2421)
# Accuracy: 0.7091454272863568
# Accuracy: 0.7038834951456311
# Train Data Shape:  (2441, 2240)
# Test Data Shape:  (616, 2240)
# Accuracy: 0.702922077922078
# Train Data Shape:  (2428, 2228)
# Test Data Shape:  (612, 2228)
# Accuracy: 0.7058823529411765
# Train Data Shape:  (2410, 2212)
# Test Data Shape:  (606, 2212)
# Accuracy: 0.7013201320132013
# Train Data Shape:  (2390, 2194)
# Test Data Shape:  (603, 2194)
# Accuracy: 0.7048092868988391
# Train Data Shape:  (2378, 2183)
# Test Data Shape:  (597, 2183)
# Accuracy: 0.6817420435510888
# Train Data Shape:  (2350, 2158)
# Test Data Shape:  (592, 2158)
# Accuracy: 0.7027027027027027
# Train Data Shape:  (2336, 2146)
# Test Data Shape:  (588, 2146)
# Accuracy: 0.6836734693877551
# Train Data Shape:  (2321, 2132)
# Test Data Shape:  (585, 2132)
# Accuracy: 0.6837606837606838
# Train Data Shape:  (2302, 2115)
# Test Data Shape:  (579, 2115)
# Accuracy: 0.7012089810017271
# Train Data Shape:  (2282, 2097)
# Test Data Shape:  (576, 2097)
# Accuracy: 0.671875
# Train Data Shape:  (2264, 2081)
# Test Data Shape:  (571, 2081)
# Accuracy: 0.670753064798599
# Train Data Shape:  (2246, 2065)
# Test Data Shape:  (567, 2065)
# Accuracy: 0.6878306878306878
# Train Data Shape:  (2226, 2047)
# Test Data Shape:  (560, 2047)
# Accuracy: 0.6892857142857143
# Train Data Shape:  (2213, 2035)
# Test Data Shape:  (555, 2035)
# Accuracy: 0.6882882882882883
# Train Data Shape:  (2193, 2017)
# Test Data Shape:  (552, 2017)
# Accuracy: 0.6956521739130435
# Train Data Shape:  (2172, 1998)
# Test Data Shape:  (549, 1998)
# Accuracy: 0.6939890710382514
# Train Data Shape:  (2155, 1983)
# Test Data Shape:  (544, 1983)
# Accuracy: 0.6948529411764706
# Train Data Shape:  (2141, 1970)
# Test Data Shape:  (542, 1970)
# Accuracy: 0.6918819188191881
# Train Data Shape:  (2132, 1962)
# Test Data Shape:  (538, 1962)
# Accuracy: 0.6784386617100372
# Train Data Shape:  (2117, 1949)
# Test Data Shape:  (535, 1949)
# Accuracy: 0.680373831775701
# Train Data Shape:  (2102, 1935)
# Test Data Shape:  (529, 1935)
# Accuracy: 0.6918714555765595
# Train Data Shape:  (2077, 1913)
# Test Data Shape:  (524, 1913)
# Accuracy: 0.6793893129770993
# Train Data Shape:  (2058, 1896)
# Test Data Shape:  (519, 1896)
# Accuracy: 0.6705202312138728
# Train Data Shape:  (2041, 1880)
# Test Data Shape:  (518, 1880)
# Accuracy: 0.6583011583011583
# Train Data Shape:  (2029, 1869)
# Test Data Shape:  (513, 1869)
# Accuracy: 0.6744639376218323
# Train Data Shape:  (2014, 1856)
# Test Data Shape:  (507, 1856)
# Accuracy: 0.6706114398422091
# Train Data Shape:  (1987, 1831)
# Test Data Shape:  (502, 1831)
# Accuracy: 0.6892430278884463
# Train Data Shape:  (1963, 1810)
# Test Data Shape:  (497, 1810)
# Accuracy: 0.6680080482897385
# Train Data Shape:  (1940, 1789)
# Test Data Shape:  (489, 1789)
# Accuracy: 0.6523517382413088
# Train Data Shape:  (1916, 1767)
# Test Data Shape:  (485, 1767)
# Accuracy: 0.6783505154639176
# Train Data Shape:  (1892, 1745)
# Test Data Shape:  (479, 1745)
# Accuracy: 0.6722338204592901
# Train Data Shape:  (1876, 1731)
# Test Data Shape:  (474, 1731)
# Accuracy: 0.6687763713080169
# Train Data Shape:  (1848, 1705)
# Test Data Shape:  (467, 1705)
# Accuracy: 0.6509635974304069
# Train Data Shape:  (1818, 1678)
# Test Data Shape:  (460, 1678)
# Accuracy: 0.6543478260869565
# Train Data Shape:  (1796, 1658)
# Test Data Shape:  (455, 1658)
# Accuracy: 0.6593406593406593
# Train Data Shape:  (1778, 1642)
# Test Data Shape:  (452, 1642)
# Accuracy: 0.6305309734513275
# Train Data Shape:  (1758, 1624)
# Test Data Shape:  (446, 1624)
# Accuracy: 0.625560538116592
# Train Data Shape:  (1739, 1606)
# Test Data Shape:  (440, 1606)
# Accuracy: 0.6295454545454545
# Train Data Shape:  (1720, 1589)
# Test Data Shape:  (434, 1589)
# Accuracy: 0.6359447004608295
# Train Data Shape:  (1697, 1568)
# Test Data Shape:  (429, 1568)
# Accuracy: 0.6223776223776224
# Train Data Shape:  (1670, 1544)
# Test Data Shape:  (423, 1544)
# Accuracy: 0.640661938534279
# Train Data Shape:  (1642, 1518)
# Test Data Shape:  (415, 1518)
# Accuracy: 0.6313253012048192
# Train Data Shape:  (1612, 1491)
# Test Data Shape:  (406, 1491)
# Accuracy: 0.6330049261083743
# Train Data Shape:  (1590, 1471)
# Test Data Shape:  (402, 1471)
# Accuracy: 0.6169154228855721
# Train Data Shape:  (1567, 1450)
# Test Data Shape:  (397, 1450)
# Accuracy: 0.6120906801007556
# Train Data Shape:  (1547, 1431)
# Test Data Shape:  (391, 1431)
# Accuracy: 0.5959079283887468
# Train Data Shape:  (1524, 1411)
# Test Data Shape:  (387, 1411)
# Accuracy: 0.6124031007751938
# Train Data Shape:  (1497, 1386)
# Test Data Shape:  (380, 1386)
# Accuracy: 0.65
# Train Data Shape:  (1480, 1370)
# Test Data Shape:  (375, 1370)
# Accuracy: 0.5973333333333334
# Train Data Shape:  (1457, 1349)
# Test Data Shape:  (370, 1349)
# Accuracy: 0.6162162162162163
# Train Data Shape:  (1436, 1330)
# Test Data Shape:  (365, 1330)
# Accuracy: 0.6356164383561644
# Train Data Shape:  (1418, 1314)
# Test Data Shape:  (358, 1314)
# Accuracy: 0.6256983240223464
# Train Data Shape:  (1395, 1293)
# Test Data Shape:  (352, 1293)
# Accuracy: 0.6051136363636364
# Train Data Shape:  (1375, 1274)
# Test Data Shape:  (351, 1274)
# Accuracy: 0.584045584045584
# Train Data Shape:  (1359, 1260)
# Test Data Shape:  (345, 1260)
# Accuracy: 0.5826086956521739
# Train Data Shape:  (1344, 1246)
# Test Data Shape:  (341, 1246)
# Accuracy: 0.5835777126099707
# Train Data Shape:  (1325, 1229)
# Test Data Shape:  (337, 1229)
# Accuracy: 0.599406528189911
# Train Data Shape:  (1304, 1209)
# Test Data Shape:  (331, 1209)
# Accuracy: 0.5709969788519638
# Train Data Shape:  (1281, 1188)
# Test Data Shape:  (324, 1188)
# Accuracy: 0.5925925925925926
# Train Data Shape:  (1259, 1168)
# Test Data Shape:  (319, 1168)
# Accuracy: 0.5768025078369906
# Train Data Shape:  (1232, 1143)
# Test Data Shape:  (313, 1143)
# Accuracy: 0.5718849840255591
# Train Data Shape:  (1210, 1123)
# Test Data Shape:  (309, 1123)
# Accuracy: 0.5598705501618123
# Train Data Shape:  (1189, 1104)
# Test Data Shape:  (303, 1104)
# Accuracy: 0.5478547854785478
# Train Data Shape:  (1170, 1087)
# Test Data Shape:  (297, 1087)
# Accuracy: 0.5454545454545454
# Train Data Shape:  (1149, 1067)
# Test Data Shape:  (292, 1067)
# Accuracy: 0.5068493150684932
# Train Data Shape:  (1123, 1043)
# Test Data Shape:  (287, 1043)
# Accuracy: 0.5644599303135889
# Train Data Shape:  (1106, 1028)
# Test Data Shape:  (281, 1028)
# Accuracy: 0.604982206405694
# Train Data Shape:  (1084, 1007)
# Test Data Shape:  (276, 1007)
# Accuracy: 0.5833333333333334
# Train Data Shape:  (1060, 985)
# Test Data Shape:  (270, 985)
# Accuracy: 0.5259259259259259
# Train Data Shape:  (1039, 966)
# Test Data Shape:  (263, 966)
# Accuracy: 0.5399239543726235
# Train Data Shape:  (1018, 947)
# Test Data Shape:  (260, 947)
# Accuracy: 0.5192307692307693
# Train Data Shape:  (1000, 930)
# Test Data Shape:  (257, 930)
# Accuracy: 0.5175097276264592
# Train Data Shape:  (984, 915)
# Test Data Shape:  (251, 915)
# Accuracy: 0.5099601593625498
# Train Data Shape:  (972, 904)
# Test Data Shape:  (248, 904)
# Accuracy: 0.5120967741935484
# Train Data Shape:  (964, 897)
# Test Data Shape:  (246, 897)
# Accuracy: 0.508130081300813
# Train Data Shape:  (942, 877)
# Test Data Shape:  (240, 877)
# Accuracy: 0.48333333333333334
# Train Data Shape:  (920, 856)
# Test Data Shape:  (235, 856)
# Accuracy: 0.48936170212765956
# Train Data Shape:  (906, 843)
# Test Data Shape:  (231, 843)
# Accuracy: 0.48917748917748916
# Train Data Shape:  (891, 830)
# Test Data Shape:  (229, 830)
# Accuracy: 0.4672489082969432
# Train Data Shape:  (880, 819)
# Test Data Shape:  (225, 819)
# Accuracy: 0.5022222222222222
# Train Data Shape:  (868, 808)
# Test Data Shape:  (224, 808)
# Accuracy: 0.45982142857142855
# Train Data Shape:  (855, 796)
# Test Data Shape:  (218, 796)
# Accuracy: 0.536697247706422
# Train Data Shape:  (834, 777)
# Test Data Shape:  (214, 777)
# Accuracy: 0.48130841121495327
# Train Data Shape:  (823, 767)
# Test Data Shape:  (211, 767)
# Accuracy: 0.4976303317535545
# Train Data Shape:  (805, 750)
# Test Data Shape:  (209, 750)
# Accuracy: 0.5167464114832536
# Train Data Shape:  (795, 741)
# Test Data Shape:  (203, 741)
# Accuracy: 0.4975369458128079
# Train Data Shape:  (781, 728)
# Test Data Shape:  (200, 728)
# Accuracy: 0.495
# Train Data Shape:  (764, 712)
# Test Data Shape:  (195, 712)
# Accuracy: 0.517948717948718
# Train Data Shape:  (745, 695)
# Test Data Shape:  (191, 695)
# Accuracy: 0.44502617801047123
# Train Data Shape:  (730, 681)
# Test Data Shape:  (188, 681)
# Accuracy: 0.4787234042553192
# Train Data Shape:  (722, 673)
# Test Data Shape:  (185, 673)
# Accuracy: 0.3945945945945946
# Train Data Shape:  (712, 664)
# Test Data Shape:  (182, 664)
# Accuracy: 0.45054945054945056
# Train Data Shape:  (701, 654)
# Test Data Shape:  (180, 654)
# Accuracy: 0.4722222222222222
# Train Data Shape:  (692, 646)
# Test Data Shape:  (178, 646)
# Accuracy: 0.48314606741573035
# Train Data Shape:  (685, 639)
# Test Data Shape:  (173, 639)
# Accuracy: 0.4277456647398844
# Train Data Shape:  (673, 628)
# Test Data Shape:  (173, 628)
# Accuracy: 0.43352601156069365
# Train Data Shape:  (658, 614)
# Test Data Shape:  (170, 614)
# Accuracy: 0.5176470588235295
# Train Data Shape:  (653, 609)
# Test Data Shape:  (169, 609)
# Accuracy: 0.47337278106508873
# Train Data Shape:  (645, 602)
# Test Data Shape:  (168, 602)
# Accuracy: 0.3869047619047619
# Train Data Shape:  (638, 595)
# Test Data Shape:  (164, 595)
# Accuracy: 0.4573170731707317
# Train Data Shape:  (625, 583)
# Test Data Shape:  (161, 583)
# Accuracy: 0.4782608695652174
# Train Data Shape:  (618, 577)
# Test Data Shape:  (159, 577)
# Accuracy: 0.42138364779874216
# Train Data Shape:  (609, 569)
# Test Data Shape:  (157, 569)
# Accuracy: 0.45222929936305734
# Train Data Shape:  (604, 564)
# Test Data Shape:  (156, 564)
# Accuracy: 0.38461538461538464
# Train Data Shape:  (590, 551)
# Test Data Shape:  (153, 551)
# Accuracy: 0.3202614379084967
# Train Data Shape:  (583, 544)
# Test Data Shape:  (150, 544)
# Accuracy: 0.44
# Train Data Shape:  (579, 541)
# Test Data Shape:  (149, 541)
# Accuracy: 0.33557046979865773
# Train Data Shape:  (569, 531)
# Test Data Shape:  (148, 531)
# Accuracy: 0.43243243243243246
# Train Data Shape:  (556, 519)
# Test Data Shape:  (146, 519)
# Accuracy: 0.410958904109589
# Train Data Shape:  (541, 505)
# Test Data Shape:  (141, 505)
# Accuracy: 0.3120567375886525
# Train Data Shape:  (524, 490)
# Test Data Shape:  (132, 490)
# Accuracy: 0.25757575757575757
# Train Data Shape:  (487, 455)
# Test Data Shape:  (127, 455)
# Accuracy: 0.31496062992125984
# Train Data Shape:  (431, 403)
# Test Data Shape:  (112, 403)
# Accuracy: 0.2767857142857143
# Train Data Shape:  (365, 341)
# Test Data Shape:  (96, 341)
# Accuracy: 0.34375
# Train Data Shape:  (288, 270)
# Test Data Shape:  (77, 270)
# Accuracy: 0.24675324675324675
# Train Data Shape:  (172, 161)
# Test Data Shape:  (47, 161)
# Accuracy: 0.2765957446808511
# Train Data Shape:  (70, 65)
# Test Data Shape:  (22, 65)
# Accuracy: 0.2727272727272727

# %%
# print(type(preds))

# %%
# print(type(y_test))
